# %% [markdown]
# ## Filter
# One of the most powerful parameters when defining a search is the ability to filter the results.  While a Query is more of an unstructured approach to search for text within documents, a Filter provides a well-defined structured approach when we know which properties we want to restrict our matching documents.
#
# The following examples will be using some of the popular properties as outlined within the "Properties & Metadata" notebook.  In addition, the selection of these properties was determined based on the discovery techniques used such as metadata and debugging.

# %%
import refinitiv.dataplatform as rdp
import pandas as pd
import datetime as dt
import dateutil.relativedelta

rdp.open_desktop_session('Your API Key here')

# %%
pd.set_option('display.max_colwidth', 140)
rdp.__version__
# Out:
# '1.0.0a7.post1'

# %% [markdown]
# #### Example - Query vs Filter
# As you become more familiar with Search, you will realize there are a number of different paths you can take to arrive at the same destination.

# %%
# Retrieve the document(s) for a specific ISIN using a Query.
rdp.search(
    view = rdp.SearchViews.Instruments,
    query = 'US046353AQ14',
    select = 'DocumentTitle, RIC, ISIN, CUSIP, SEDOL, PermID'
)
# Out:
#                                                                             DocumentTitle  \
# 0  AstraZeneca PLC, Plain Vanilla Fixed Coupon Bond, TRACE Eligible AZN 2.375 12-Jun-2022
#
#            ISIN       PermID    SEDOL      CUSIP         RIC
# 0  US046353AQ14  46645702869  BF4SNM7  046353AQ1  046353AQ1=

# %%
# Retrieve the document(s) for the same ISIN using a Filter
rdp.search(
    view = rdp.SearchViews.Instruments,
    filter = "ISIN eq 'US046353AQ14'",
    select = 'DocumentTitle, RIC, ISIN, CUSIP, SEDOL, PermID'
)
# Out:
#                                                                             DocumentTitle  \
# 0  AstraZeneca PLC, Plain Vanilla Fixed Coupon Bond, TRACE Eligible AZN 2.375 12-Jun-2022
#
#            ISIN       PermID    SEDOL      CUSIP         RIC
# 0  US046353AQ14  46645702869  BF4SNM7  046353AQ1  046353AQ1=

# %%
# If you are provided a code but are not sure if the code is an ISIN, SEDOL, CUSIP etc, 
# try using the 'CodeResolutionBase' property.
rdp.search(
    view = rdp.SearchViews.Instruments,
    filter = "CodeResolutionBase eq '046353AQ1'",   # I'm using the CUSIP for the same instrument
    select = 'DocumentTitle, RIC, ISIN, CUSIP, SEDOL, PermID'
)
# Out:
#                                                                             DocumentTitle  \
# 0  AstraZeneca PLC, Plain Vanilla Fixed Coupon Bond, TRACE Eligible AZN 2.375 12-Jun-2022
#
#            ISIN       PermID    SEDOL      CUSIP         RIC
# 0  US046353AQ14  46645702869  BF4SNM7  046353AQ1  046353AQ1=

# %% [markdown]
# #### Example - Apple Equities

# %%
# Within the view (EquityQuotes), select all documents where the term 'AAPL' is within the ticker symbol.  For each, 
# ensure the type of asset is an 'equity' and that each asset is in an active state.  I chose to filter out the 
# AssetState of 'DC' (De-activated) as my criteria.
#
# Note: An alternative to "AssetType eq 'equity'" could be to use: "RCSAssetCategoryLeaf eq 'Ordinary Share'"
rdp.search(
    view = rdp.SearchViews.EquityQuotes,
    filter = "AssetType eq 'equity' and AssetState ne 'DC' and TickerSymbol eq 'AAPL'",
    select = "RIC, CompositeDescriptiveName, ExchangeCode, ExchangeName, AssetType"
)
# Out:
#   AssetType           CompositeDescriptiveName          RIC  \
# 0  [EQUITY]            Apple Ord Shs APPLE ORD       AAPL.O
# 1  [EQUITY]  Apple Ord Shs APPLE ORD APPLE INC  AAPLEUR.xbo
# 2  [EQUITY]            Apple Ord Shs APPLE ORD      AAPL.OQ
# 3  [EQUITY]            Apple Ord Shs APPLE ORD      AAPL.DG
# 4  [EQUITY]  Apple Ord Shs APPLE ORD APPLE INC       AAPL.Z
# 5  [EQUITY]            Apple Ord Shs APPLE ORD       AAPL.B
# 6  [EQUITY]            Apple Ord Shs APPLE ORD     AAPLE.MI
# 7  [EQUITY]  Apple Ord Shs APPLE ORD APPLE INC      AAPL.ZY
# 8  [EQUITY]  Apple Ord Shs APPLE ORD APPLE INC      AAPL.PH
# 9  [EQUITY]            Apple Ord Shs APPLE ORD      AAPL.DY
#
#                                          ExchangeName ExchangeCode
# 0                   NASDAQ Global Select Consolidated          NSQ
# 1                MiFID Composite Cross Market Service          XBO
# 2          NASDAQ Stock Exchange Global Select Market          NSM
# 3    Cboe EDGX Exchange - Nasdaq Global Select Market          GCD
# 4     Cboe BZX Exchange - Nasdaq Global Select Market          GCZ
# 5  Boston SE when trading NASDAQ Global Select Market          GSB
# 6                                Milan Stock Exchange          MIL
# 7     Cboe BYX Exchange - Nasdaq Global Select Market          GCY
# 8                NASDAQ OMX PHLX Global Select Market          GSX
# 9    Cboe EDGA Exchange - Nasdaq Global Select Market          GDA

# %% [markdown]
# #### Example - Vessels
# List all Very Large Gas Containers (VLGC) that are in service within the last week.

# %%
# Build date range expression for the location of the vessel for the last 7 days
date_7_days_ago = dt.datetime.today() - dateutil.relativedelta.relativedelta(days=7)
date_range = f'LocationTimestamp ge {date_7_days_ago.strftime("%Y-%m-%d")} and \
               LocationTimestamp lt {dt.datetime.today().strftime("%Y-%m-%d")}'

# %%
# Show the location of each vessel and some general details such as location, destination and coordinates.
rdp.search(
    view = rdp.SearchViews.VesselPhysicalAssets,
    filter = f"RCSAssetTypeLeaf eq 'VLGC' and VesselStatus eq 'IN SERVICE' and {date_range}",
    select = 'RIC, SynonymSearchAll, DTSource, LocationTimestamp, IMO,Latitude, Longitude, LocationDestination',
    top=100
)
# Out:
#      Longitude         LocationTimestamp  \
# 0    33.153282  2020-12-09T07:47:24.000Z
# 1   113.839073  2020-12-09T21:08:19.000Z
# 2   130.100449  2020-12-09T13:59:15.000Z
# 3   -97.569687  2020-12-08T23:00:18.000Z
# 4    66.395981  2020-12-08T18:31:51.000Z
# 5    72.558334  2020-12-08T03:28:56.000Z
# 6    -0.345000  2020-12-08T06:52:52.000Z
# 7    50.810871  2020-12-08T05:21:55.000Z
# 8   104.460350  2020-12-09T18:01:58.000Z
# 9    87.088913  2020-12-09T23:30:18.000Z
# 10  122.672073  2020-12-08T19:43:12.000Z
# 11   74.164673  2020-12-09T00:18:39.000Z
# 12  121.198563  2020-12-09T11:08:34.000Z
# 13   55.544899  2020-12-06T18:30:51.000Z
# 14  104.397842  2020-12-09T01:06:32.000Z
# 15  129.422043  2020-12-08T07:55:34.000Z
# 16  -95.124786  2020-12-09T10:29:24.000Z
# 17  108.178230  2020-12-09T11:21:46.000Z
# 22  C}KY7309456906  8818219                   SINGAPORE [Singapore]
# 23  C}KY7309467141  9012886                 LONGKOU,CHINA [Longkou]
# 24  C}KY7309468382  9031519               KHOR FAKKAN [Khor Fakkan]
# 25  C}KY7309480542  9206396                       CN DGG [Dongguan]
# 26  C}KY7309486846  9290270                        PANJIN [Yingkou]
# 27  C}KY7309466510  9002491                           SOHAR [Sohar]

# %% [markdown]
# #### Example - Floating Rate Notes
# Retrieve all floating rate notes (floating coupon) in the healthcare sector which are issued in Euros.  For each, ensure the coupon rate is great than 2 and our Moody's rating is greater than 'Baa1'.
#
# To determine the rating, we apply the following logic utilizing the RatingsScope property - which is a nested property providing additional details:
#
# - RatingsScope(RatingType eq 'MIS' and CurrentRatingRank lt 10)
#
# The RatingType of 'MIS' refers to the "Moody's Long-term Issuer Rating".
# The CurrentRatingRank < 10 instructs search to look for ratings less than 10 ('Baa1').  **Note**: The lower the rank, the better the rating.

# %%
rdp.search(
    view = rdp.SearchViews.GovCorpInstruments,
    filter = "CouponRate gt 2 and \
              RatingsScope(RatingType eq 'MIS' and CurrentRatingRank lt 10) and \
              RCSCouponTypeName eq 'Floating Coupon' and \
              IsActive eq true and \
              RCSTRBC2012Name eq 'Healthcare' and \
              RCSCurrencyLeaf xeq 'Euro'",
    select = "CouponCurrency, IssuerName, IssueDate, RIC, CouponRate, ISIN, Ticker, RCSTRBC2012Leaf, MaturityDate, AssetState",   
)
# Out:
#   IssuerName          ISIN CouponCurrency        RCSTRBC2012Leaf Ticker  \
# 0  Sanofi FR  FR0000140022            EUR  Pharmaceuticals (NEC)   SASY
# 1  Sanofi FR  FR0000047656            EUR  Pharmaceuticals (NEC)   SASY
#
#              RIC                 IssueDate  CouponRate
# 0  FR0000140022=  1983-07-01T00:00:00.000Z        15.5
# 1  AVEPpaEUR.MIp  1987-10-01T00:00:00.000Z        15.5

# %% [markdown]
# #### Example - Outstanding Green Bonds
# List the outstanding Green Bonds for Telefonica.

# %%
rdp.search(
    view = rdp.SearchViews.GovCorpInstruments,
    filter = "IssuerName eq 'Telefonica' and IsGreenBond eq true",
    select = "IssuerName, DocumentTitle, RIC, CouponRate, ISIN, IssuerTicker, DebtTypeDescription, EOMAmountOutstanding, FaceOutstanding"
)
# Out:
#                                                                       DocumentTitle  \
# 0                                             Telefonica Europe BV, Bond, TEF 2.502
# 1  Telefonica Emisiones SAU, Plain Vanilla Fixed Coupon Bond, TEF 1.069 05-Feb-2024
#
#            ISIN        IssuerName IssuerTicker       DebtTypeDescription  \
# 0  XS2109819859  Telefonica Europ        TEFBV  Junior Subordinated Note
# 1  XS1946004451   Telefonica Emis       TEFEMI               Senior Note
#
#    FaceOutstanding           RIC  CouponRate  EOMAmountOutstanding
# 0        500000000  ES210981985=       2.502             500000000
# 1       1000000000  ES194600445=       1.069            1000000000

# %% [markdown]
# #### Example - Equity Index listing in the U.S.A

# %%
# Based on the Asset Category (Equity Index), list the top 10 indexes within the USA.
rdp.search(
    view = rdp.SearchViews.IndexInstruments,
    filter = "RCSIndexCountryGroupLeaf xeq 'United States' and RCSAssetCategoryLeaf xeq 'Equity Index'",
    select = "DocumentTitle, RIC, RCSTRBC2012Leaf"
)
# Out:
#                                                     RCSTRBC2012Leaf  \
# 0                                       Trade & Business Publishing
# 1                                               Magazine Publishing
# 2                                              UK Investment Trusts
# 3  Financial & Commodity Market Operators & Service Providers (NEC)
# 4                           Professional Information Services (NEC)
# 5                                       Trade & Business Publishing
# 6                                       Trade & Business Publishing
# 7                                       Trade & Business Publishing
# 8                                               Magazine Publishing
# 9                                               Magazine Publishing
#
#                                               DocumentTitle         RIC
# 0          Dow Jones Industrial Average Index, Equity Index        .DJI
# 1                        S&P 500 Index - CBOE, Equity Index        .SPX
# 2                            NASDAQ 100 Index, Equity Index        .NDX
# 3                      NASDAQ Composite Index, Equity Index       .IXIC
# 4  Refinitiv United States Price Return Index, Equity Index  .TRXFLDUSP
# 5           Dow Jones Transport Average Index, Equity Index        .DJT
# 6                   Dow Jones Composite Index, Equity Index        .DJA
# 7             Dow Jones Utility Average Index, Equity Index        .DJU
# 8                     S&P 600 Small Cap Index, Equity Index       .SPCY
# 9                         S&P 500 Index - CME, Equity Index        .INX

# %% [markdown]
# #### Example - Search for Brazil global sovereign bonds in USD with a duration greater than 1

# %%
rdp.search(
    view=rdp.SearchViews.FixedIncomeInstruments,
    filter = "RCSIssuerCountryLeaf eq 'Brazil' and \
              RCSCurrencyLeaf eq 'US Dollar' and \
              RCSTRBC2012Leaf eq 'Government & Government Finance' and \
              OptionAdjustedDuration gt 1",
    select ="RIC, ISIN, MaturityDate, CouponRate, IndustrySector, FaceOutstandingUSD, OptionAdjustedDuration"
)
# Out:
#   IndustrySector          ISIN  FaceOutstandingUSD  OptionAdjustedDuration  \
# 0       SOVERGRN  US105756BU30          2150000000                1.995180
# 1       SOVERGRN  US105756AR10          1029030000                2.959345
# 2       SOVERGRN  US105756AZ36            85557000                2.959345
# 3       SOVERGRN  US105756BV13          4300000000                3.698457
# 4       SOVERGRN  US105756BF62           688201000                3.514352
# 5       SOVERGRN  US105756CD06          1750000000                4.199081
# 6       SOVERGRN  US105756BX78          2176245000                4.608230
# 7       SOVERGRN  US105756AE07           765023000                5.052952
# 8       SOVERGRN  US105756BZ27          3000000000                5.823233
# 9       SOVERGRN  US105756CA66          2000000000                6.928336
#
#             RIC  CouponRate              MaturityDate
# 0    105756BU3=       2.625  2023-01-05T00:00:00.000Z
# 1  BR012631375=       8.875  2024-04-15T00:00:00.000Z
# 2  BR017244388=       8.875  2024-04-15T00:00:00.000Z
# 3    105756BV1=       4.250  2025-01-07T00:00:00.000Z
# 4  BR021210641=       8.750  2025-02-04T00:00:00.000Z
# 5    105756CD0=       2.875  2025-06-06T00:00:00.000Z
# 6    105756BX7=       6.000  2026-04-07T00:00:00.000Z
# 7    105756AE0=      10.125  2027-05-15T00:00:00.000Z
# 8    105756BZ2=       4.625  2028-01-13T00:00:00.000Z
# 9    105756CA6=       4.500  2029-05-30T00:00:00.000Z

# %%
# Alternatively, you have the option of trying it this way which will render the same results
rdp.search(
    view=rdp.SearchViews.FixedIncomeInstruments,
    filter = "IssuerCountryName eq 'Brazil' and \
              OptionAdjustedDuration gt 1 and \
              Currency eq 'USD' and IndustrySectorDescription eq 'Sovereign'",
    select ="RIC, ISIN, MaturityDate, CouponRate,IndustrySector, FaceOutstandingUSD, OptionAdjustedDuration"
)
# Out:
#   IndustrySector          ISIN  FaceOutstandingUSD  OptionAdjustedDuration  \
# 0       SOVERGRN  US105756BU30          2150000000                1.995180
# 1       SOVERGRN  US105756AR10          1029030000                2.959345
# 2       SOVERGRN  US105756AZ36            85557000                2.959345
# 3       SOVERGRN  US105756BV13          4300000000                3.698457
# 4       SOVERGRN  US105756BF62           688201000                3.514352
# 5       SOVERGRN  US105756CD06          1750000000                4.199081
# 6       SOVERGRN  US105756BX78          2176245000                4.608230
# 7       SOVERGRN  US105756AE07           765023000                5.052952
# 8       SOVERGRN  US105756BZ27          3000000000                5.823233
# 9       SOVERGRN  US105756CA66          2000000000                6.928336
#
#             RIC  CouponRate              MaturityDate
# 0    105756BU3=       2.625  2023-01-05T00:00:00.000Z
# 1  BR012631375=       8.875  2024-04-15T00:00:00.000Z
# 2  BR017244388=       8.875  2024-04-15T00:00:00.000Z
# 3    105756BV1=       4.250  2025-01-07T00:00:00.000Z
# 4  BR021210641=       8.750  2025-02-04T00:00:00.000Z
# 5    105756CD0=       2.875  2025-06-06T00:00:00.000Z
# 6    105756BX7=       6.000  2026-04-07T00:00:00.000Z
# 7    105756AE0=      10.125  2027-05-15T00:00:00.000Z
# 8    105756BZ2=       4.625  2028-01-13T00:00:00.000Z
# 9    105756CA6=       4.500  2029-05-30T00:00:00.000Z

# %% [markdown]
# #### Example - Top executives

# %%
# Using the People View, we can utilize the OfficerDirector property, which contains a number of nested or sub-properties 
# that allow me to perform a more fine-grained search against active people that have been assigned a title code of 
# CEO (Chief Executive Officer). The results are listed based on a default rank defined by the search service.
rdp.search(
    view = rdp.SearchViews.People,
    filter = "OfficerDirector(RoleTitleCode eq 'CEO' and RoleStatus eq 'Active')",
    top = 20,
    select = "FullName, PrimaryTitleAsReported, PrimaryOfficerDirector, RIC, OfficerDirectorActiveCompanies, PrimaryOfficerDirectorRIC"
)
# Out:
#        PrimaryOfficerDirector               FullName  \
# 0              Microsoft Corp  John Wendell Thompson
# 1              Microsoft Corp          Satya Nadella
# 2                   Apple Inc        Art D. Levinson
# 3                   Apple Inc            Tim D. Cook
# 4              Amazon.com Inc          Jeff P. Bezos
# 5              Amazon.com Inc  Keith Brian Alexander
# 6              Amazon.com Inc      Jon J. Rubinstein
# 7                Alphabet Inc          Sundar Pichai
# 8                Alphabet Inc      Roger W. Ferguson
# 9                Facebook Inc        Mark Zuckerberg
# 10               Facebook Inc    Dustin A. Moskovitz
# 11               Facebook Inc          Adam D'Angelo
# 12     Berkshire Hathaway Inc  Warren Edward Buffett
# 13     Berkshire Hathaway Inc        Gregory E. Abel
# 14     Berkshire Hathaway Inc         Steve B. Burke
# 15  Alibaba Group Holding Ltd           Daniel Zhang
# 16  Alibaba Group Holding Ltd              Fan Jiang
# 17       Tencent Holdings Ltd             Huateng Ma
# 18                   Visa Inc       Al Francis Kelly
# The following example will specify an underlying instrument (RIC) and pull the list of options that are active, i.e. not expired.

# %%
# Define our underlying
underlying = "'AAPL.O'"

# To search for our instrument, I'm utilizing the property: 'UnderlyingQuoteRIC'.  The property does not support an 
# exact match 'xeq', so we must use the partial match 'eq' to find all hits. Depending on the instrument you specify, 
# this may introduce additional hits.  For example, if you are using the underlying 'AAPL.O', search will also find a 
# hit on 'AAPL.OQ', for example. To protect against this, we can utilize a combination of the built-in functions, 
# 'startswith' and 'endwith' to perform our match.
rdp.search(
    view = rdp.SearchViews.EquityDerivativeQuotes,
    filter = "AssetState eq 'AC' and \
              startswith(UnderlyingQuoteRIC, " + underlying + ") and \
              endswith(UnderlyingQuoteRIC," + underlying + ") and \
              RCSAssetClass eq 'OPT' and IsChain eq false and \
              ExpiryDate ge " + dt.datetime.today().strftime('%Y-%m-%d'),
    select = "DocumentTitle, RIC, ExpiryDate, CallPutOption, StrikePrice",
    top = 10000
)
# Out:
#                                                                                         DocumentTitle  \
# 0       OPRA Apple Equity Option 120 Put Feb 2021 , Equity Cash Option, Put 120 USD 19-Feb-2021, OPRA
# 1     OPRA Apple Equity Option 130 Call Feb 2021 , Equity Cash Option, Call 130 USD 19-Feb-2021, OPRA
# 2     OPRA Apple Equity Option 125 Call Feb 2021 , Equity Cash Option, Call 125 USD 19-Feb-2021, OPRA
# 3       OPRA Apple Equity Option 130 Put Feb 2021 , Equity Cash Option, Put 130 USD 19-Feb-2021, OPRA
# 4     OPRA Apple Equity Option 120 Call Feb 2021 , Equity Cash Option, Call 120 USD 19-Feb-2021, OPRA
# ...                                                                                               ...
# 2151    OPRA Apple Equity Option 143 Put Mar 2021 , Equity Cash Option, Put 143 USD 05-Mar-2021, OPRA
# 2152  OPRA Apple Equity Option 129 Call Mar 2021 , Equity Cash Option, Call 129 USD 05-Mar-2021, OPRA
# 2153    OPRA Apple Equity Option 125 Put Mar 2021 , Equity Cash Option, Put 125 USD 05-Mar-2021, OPRA
# 2154    OPRA Apple Equity Option 128 Put Mar 2021 , Equity Cash Option, Put 128 USD 05-Mar-2021, OPRA
# 2155    OPRA Apple Equity Option 142 Put Mar 2021 , Equity Cash Option, Put 142 USD 05-Mar-2021, OPRA
#
#      CallPutOption  StrikePrice               RIC                ExpiryDate
# 0              Put        120.0  AAPLN192112000.U  2021-02-19T00:00:00.000Z
# 1             Call        130.0  AAPLB192113000.U  2021-02-19T00:00:00.000Z
# 2             Call        125.0  AAPLB192112500.U  2021-02-19T00:00:00.000Z
# 3              Put        130.0  AAPLN192113000.U  2021-02-19T00:00:00.000Z
# 4             Call        120.0  AAPLB192112000.U  2021-02-19T00:00:00.000Z
# ...            ...          ...               ...                       ...
# 2151           Put        143.0  AAPLO052114300.U  2021-03-05T00:00:00.000Z
# 2152          Call        129.0  AAPLC052112900.U  2021-03-05T00:00:00.000Z
# 2153           Put        125.0  AAPLO052112500.U  2021-03-05T00:00:00.000Z
# 2154           Put        128.0  AAPLO052112800.U  2021-03-05T00:00:00.000Z
# 2155           Put        142.0  AAPLO052114200.U  2021-03-05T00:00:00.000Z
#
# [2156 rows x 5 columns]
