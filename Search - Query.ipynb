# %%
import refinitiv.dataplatform as rdp
import pandas as pd

rdp.open_desktop_session('Your API Key here')

# %%
pd.set_option('display.max_colwidth', 140)
rdp.__version__
# Out:
# '1.0.0a7.post1'

# %% [markdown]
# ### Query
# The most basic search that can be performed is the query.  The query is a free-formed text expression, similar to the type of query you can perform within Google, matching against documents within the specified view.

# %%
# The default syntax for search is to specify a query expression.  By default, search will return a default set of 
# fields (Properties).
rdp.search('IBM')
# Out:
#            PI BusinessEntity       PermID  \
# 0       37036   ORGANISATION         <NA>
# 1     1097326   QUOTExEQUITY  55839165994
# 2       99244   ORGANISATION         <NA>
# 3  4297694029           ORGS         <NA>
# 4    18062670   ORGANISATION         <NA>
# 5    27968389   ORGANISATION         <NA>
# 6    48924732   QUOTExEQUITY  21481052421
# 7   259118763   QUOTExEQUITY  21612423771
# 8    49450681   QUOTExEQUITY  21481052892
# 9    50092347   QUOTExEQUITY  21481053949
#
#                                                                                     DocumentTitle  \
# 0                                            International Business Machines Corp, Public Company
# 1                         International Business Machines Corp, Ordinary Share, NYSE Consolidated
# 2                                                                 IBM Credit LLC, Private Company
# 3                                                      IBM Retirement Fund Trust, Private Company
# 4               Tiers Corporate Bond Backed Certificates Trust Series Ibm 1997 4, Private Company
# 5                      SG Stuttgart Vaihingen BM-Campus 1 UG haftungsbeschraenkt, Private Company
# 6  Eurex International Business Machines Equity Future Chain Contract , Equity Future, USD, Eurex
# 7  Euronext Amsterdam IBM Dividend Future Chain Contracts, Equity Future, USD, Euronext Amsterdam
# 8   Eurex International Business Machines Equity Future Continuation 1, Equity Future, USD, Eurex
# 9   Eurex International Business Machines Equity Future Continuation 2, Equity Future, USD, Eurex
#
#         RIC
# 0      <NA>
# 1       IBM
# 2      <NA>
# 3      <NA>
# 4      <NA>
# 5      <NA>
# 6   0#IBMF:
# 7  0#IBMDF:
# 8    IBMFc1
# 9    IBMFc2

# %%
# By default, 10 documents will be returned.  Let's override that.
rdp.search(
    query = 'IBM',
    top = 20
)
# Out:
#             PI BusinessEntity       PermID  \
# 0        37036   ORGANISATION         <NA>
# 1      1097326   QUOTExEQUITY  55839165994
# 2        99244   ORGANISATION         <NA>
# 3   4297694029           ORGS         <NA>
# 4     18062670   ORGANISATION         <NA>
# 5     27968389   ORGANISATION         <NA>
# 6     48924732   QUOTExEQUITY  21481052421
# 7    259118763   QUOTExEQUITY  21612423771
# 8     49450681   QUOTExEQUITY  21481052892
# 9     50092347   QUOTExEQUITY  21481053949
# 10   260213021   QUOTExEQUITY  21613372305
# 11    50092348   QUOTExEQUITY  21481053950
# 12    50092349   QUOTExEQUITY  21481053951
# 13   260213022   QUOTExEQUITY  21613372306
# 14    50092350   QUOTExEQUITY  21481053952
# 15    50092351   QUOTExEQUITY  21481053953
# 16   260213023   QUOTExEQUITY  21613372307
# 17    50092352   QUOTExEQUITY  21481053954
# 18    50092353   QUOTExEQUITY  21481053955
# 19   260213024   QUOTExEQUITY  21613372308
#
#                                                                                                  DocumentTitle  \
# 0                                                         International Business Machines Corp, Public Company
# 1                                      International Business Machines Corp, Ordinary Share, NYSE Consolidated
# 2                                                                              IBM Credit LLC, Private Company
# 3                                                                   IBM Retirement Fund Trust, Private Company
# 4                            Tiers Corporate Bond Backed Certificates Trust Series Ibm 1997 4, Private Company
# 5                                   SG Stuttgart Vaihingen BM-Campus 1 UG haftungsbeschraenkt, Private Company
# 6               Eurex International Business Machines Equity Future Chain Contract , Equity Future, USD, Eurex
# 7               Euronext Amsterdam IBM Dividend Future Chain Contracts, Equity Future, USD, Euronext Amsterdam
# 8                Eurex International Business Machines Equity Future Continuation 1, Equity Future, USD, Eurex
# 9                Eurex International Business Machines Equity Future Continuation 2, Equity Future, USD, Eurex
# 10  Euronext Amsterdam IBM Single Stock Dividend Future Continuation 1, Equity Future, USD, Euronext Amsterdam
# 11               Eurex International Business Machines Equity Future Continuation 3, Equity Future, USD, Eurex
# 12               Eurex International Business Machines Equity Future Continuation 4, Equity Future, USD, Eurex
# 13  Euronext Amsterdam IBM Single Stock Dividend Future Continuation 2, Equity Future, USD, Euronext Amsterdam
# 14               Eurex International Business Machines Equity Future Continuation 5, Equity Future, USD, Eurex
# 15               Eurex International Business Machines Equity Future Continuation 6, Equity Future, USD, Eurex
# 16  Euronext Amsterdam IBM Single Stock Dividend Future Continuation 3, Equity Future, USD, Euronext Amsterdam
# 17               Eurex International Business Machines Equity Future Continuation 7, Equity Future, USD, Eurex
# 18               Eurex International Business Machines Equity Future Continuation 8, Equity Future, USD, Eurex
# 19  Euronext Amsterdam IBM Single Stock Dividend Future Continuation 4, Equity Future, USD, Euronext Amsterdam
#
#          RIC
# 0       <NA>
# 1        IBM
# 2       <NA>
# 3       <NA>
# 4       <NA>
# 5       <NA>
# 6    0#IBMF:
# 7   0#IBMDF:
# 8     IBMFc1
# 9     IBMFc2
# 10   IBMDFc1
# 11    IBMFc3
# 12    IBMFc4
# 13   IBMDFc2
# 14    IBMFc5
# 15    IBMFc6
# 16   IBMDFc3
# 17    IBMFc7
# 18    IBMFc8
# 19   IBMDFc4

# %% [markdown]
# If we were to type in the following expression, we might come away believing the query will list all personnel within IBM that have a title
# of CEO.  While, the results will indicate people related to IBM and people with a title of CEO, we cannot assume they are both.  That is,
# we will see results with the term IBM and CEO listed in the document.

# %%
  # Match all documents where the term IBM and CEO appear in any order
rdp.search('IBM CEO')
# Out:
#                                                                                   DocumentTitle  \
# 0     Arvind Krishna - International Business Machines Corp - Chief Executive Officer, Director
# 1                 Rudy S. Karsan - Kenexa Corp - Chairman of the Board, Chief Executive Officer
# 2  Mohammed Farooq - Gravitant Inc - Chairman of the Board, Chief Executive Officer, Co-Founder
# 3                                Deidre Paknad - Pss Systems Inc - President, CEO, Board Member
# 4                                              Ron S Dembo - Algorithmics Inc - President & CEO
# 5                                                 Frank Chisholm - Aptsoft Corp - CEO & Founder
# 6                        Michael Knagenhjelm - Metamerge As(Ibm Corp) - Chief Executive Officer
# 7                                 Bruce Miller - Tarian Software(Ibm) - Chief Executive Officer
#
#   BusinessEntity           PI       PermID
# 0         PERSON  34417810693  34417810693
# 1         PERSON  34413248256  34413248256
# 2         PERSON  34415058863  34415058863
# 3         PERSON  34414057544  34414057544
# 4         PERSON  34414091235  34414091235
# 5         PERSON  34414058841  34414058841
# 6         PERSON  34414139687  34414139687
# 7         PERSON  34414399995  34414399995

# %% [markdown]
# What might give a more favorable result would be to query all documents related to people that contain the term '*IBM*'. From the result, I can visually see
# titles and optionally filter out people that are not CEO's.  I can do this by selecting the '**People**' view.
# In addition, I'm going to choose specific *child* elements of the **DocumentTitle** field.  As we see in our output from the above requests, the
# '**DocumentTitle**' is selected by default.  This property is a convenient collection of elements that nicely describes the document returned and is
# made up of multiple sub-properties such as: '**DTSubjectName**', '**DTSimpleType**', '**DTSource**', and '**DTCharacteristics**'.
#
# By doing this, I can now see a nice
# break-down of the titles (DTCharacteristics), name (DTSubjectName) and company (DTSimpleType).

# %%
rdp.search(
    view = rdp.SearchViews.People,
    query = 'IBM',
    select = 'DocumentTitle, DTSubjectName, DTSimpleType, DTSource, DTCharacteristics'
)
# Out:
#                                                                                                                           DocumentTitle  \
# 0                                             Ginni M. Rometty - International Business Machines Corp - Executive Chairman of the Board
# 1                                                                  Jim M. Whitehurst - International Business Machines Corp - President
# 2                                             Arvind Krishna - International Business Machines Corp - Chief Executive Officer, Director
# 3     James J. Kavanaugh - International Business Machines Corp - Senior Vice President, Chief Financial Officer, Finance and operation
# 4                         Diane J. Gherson - International Business Machines Corp - Chief Human Resource Officer, Senior Vice President
# 5                                                       John E. Kelly - International Business Machines Corp - Executive Vice President
# 6                               Kenneth M. Keverian - International Business Machines Corp - Senior Vice President - Corporate Strategy
# 7  Michelle H. Browdy - International Business Machines Corp - Senior Vice President - Legal and Regulatory Affairs and General Counsel
# 8                                                Robert F. Del Bene - International Business Machines Corp - Vice President, Controller
# 9                                                      Mike L. Eskew - International Business Machines Corp - Lead Independent Director
#
#          DTSubjectName  \
# 0     Ginni M. Rometty
# 1    Jim M. Whitehurst
# 2       Arvind Krishna
# 3   James J. Kavanaugh
# 4     Diane J. Gherson
# 5        John E. Kelly
# 6  Kenneth M. Keverian
# 7   Michelle H. Browdy
# 8   Robert F. Del Bene
# 9        Mike L. Eskew
#
#                                                           DTCharacteristics  \
# 0                                           Executive Chairman of the Board
# 1                                                                 President
# 2                                         Chief Executive Officer, Director
# 3     Senior Vice President, Chief Financial Officer, Finance and operation
# 4                       Chief Human Resource Officer, Senior Vice President
# 5                                                  Executive Vice President
# 6                                Senior Vice President - Corporate Strategy
# 7  Senior Vice President - Legal and Regulatory Affairs and General Counsel
# 8                                                Vice President, Controller
# 9                                                 Lead Independent Director
#
#                            DTSimpleType
# 0  International Business Machines Corp
# 1  International Business Machines Corp
# 2  International Business Machines Corp
# 3  International Business Machines Corp
# 4  International Business Machines Corp
# 5  International Business Machines Corp
# 6  International Business Machines Corp
# 7  International Business Machines Corp
# 8  International Business Machines Corp
# 9  International Business Machines Corp

# %%
# Search for a specific ISIN using query
rdp.search('US046353AQ14')
# Out:
#                    PI                  BusinessEntity       PermID  \
# 0  0x00102cb50fde0d55  INSTRUMENTxFIXEDINCOMExGOVCORP  46645702869
# 1  0x00102c9a7ade0d0f       QUOTExFIXEDINCOMExGOVCORP         <NA>
# 2  0x00102cbda5b71586       QUOTExFIXEDINCOMExGOVCORP         <NA>
# 3  0x00102ce0bcbf19c6       QUOTExFIXEDINCOMExGOVCORP         <NA>
# 4  0x00102c435ce30dcd       QUOTExFIXEDINCOMExGOVCORP         <NA>
# 5  0x00102c4f5ce30dc1       QUOTExFIXEDINCOMExGOVCORP         <NA>
# 6  0x00102c1968121c43       QUOTExFIXEDINCOMExGOVCORP         <NA>
# 7  0x00102cadc88d0eda       QUOTExFIXEDINCOMExGOVCORP         <NA>
# 8  0x00102cc599441a3e       QUOTExFIXEDINCOMExGOVCORP         <NA>
# 9  0x00102c60801b1bdc       QUOTExFIXEDINCOMExGOVCORP         <NA>
#
#                                                                                      DocumentTitle  \
# 0           AstraZeneca PLC, Plain Vanilla Fixed Coupon Bond, TRACE Eligible AZN 2.375 12-Jun-2022
# 1                AstraZeneca PLC, Bond Quote, TRACE Eligible AZN 2.375 12-Jun-2022, MARKETAXESS L2
# 2  AstraZeneca PLC, Bond Quote, TRACE Eligible AZN 2.375 12-Jun-2022, CREDIT SUISSE TRADEWEB PRICE
# 3    AstraZeneca PLC, Bond Quote, TRACE Eligible AZN 2.375 12-Jun-2022, MARKETAXESS COMPOSITE PLUS
# 4            AstraZeneca PLC, Bond Quote, TRACE Eligible AZN 2.375 12-Jun-2022, TDS TRADEWEB PRICE
# 5                      AstraZeneca PLC, Bond Quote, TRACE Eligible AZN 2.375 12-Jun-2022, TRADEWEB
# 6                      AstraZeneca PLC, Bond Quote, TRACE Eligible AZN 2.375 12-Jun-2022, TRADEWEB
# 7                     AstraZeneca PLC, Bond Quote, TRACE Eligible AZN 2.375 12-Jun-2022, GFI GROUP
# 8          AstraZeneca PLC, Bond Quote, TRACE Eligible AZN 2.375 12-Jun-2022, MARKETAXESS AXESSALL
# 9               AstraZeneca PLC, Bond Quote, TRACE Eligible AZN 2.375 12-Jun-2022, TWEB EUCR MARKS
#
#                  RIC
# 0         046353AQ1=
# 1       046353AQ1=2M
# 2  US046353AQ14=CSTW
# 3  US046353AQ14=MKCP
# 4  US046353AQ14=TDTW
# 5    US046353AQ14=TE
# 6     046353AQ1=TWEB
# 7  US046353AQ14=GFGL
# 8  US046353AQ14=MKAX
# 9  US046353AQ14=TEMK

# %%
# Narrow the search to only instruments
rdp.search(
    view = rdp.SearchViews.Instruments,
    query = 'US046353AQ14'
)
# Out:
#                    PI                  BusinessEntity       PermID  \
# 0  0x00102cb50fde0d55  INSTRUMENTxFIXEDINCOMExGOVCORP  46645702869
#
#                                                                             DocumentTitle  \
# 0  AstraZeneca PLC, Plain Vanilla Fixed Coupon Bond, TRACE Eligible AZN 2.375 12-Jun-2022
#
#           RIC
# 0  046353AQ1=

# %% [markdown]
# #### Query Syntax
# A query phrase can support some basic syntax including wildcards, boolean expressions and exact phrase matching.

# %%
# Use a specifc term in quotes and the boolean operator to locate specific tankers - use the Content layer 
# to print additional details.
response = rdp.Search.search("'Caribbean Tanker' and Baltic")
print(f'Matched a total of {response.data.total} documents')
response.data.df
# Out:
# Matched a total of 17 documents
#             PI        BusinessEntity       PermID  \
# 0       621981       QUOTExCOMMODITY         <NA>
# 1    175653765       QUOTExCOMMODITY  21717867959
# 2     48950908       QUOTExCOMMODITY  21717782063
# 3    325658314       QUOTExCOMMODITY  21717782060
# 4  77309628067  PHYSICALASSETxVESSEL  77309628067
# 5  77309494578  PHYSICALASSETxVESSEL  77309494578
# 6  77309505681  PHYSICALASSETxVESSEL  77309505681
# 7  77309873409  PHYSICALASSETxVESSEL  77309873409
# 8  77309493434  PHYSICALASSETxVESSEL  77309493434
# 9  77309495550  PHYSICALASSETxVESSEL  77309495550
#
#                                                                                                                       DocumentTitle  \
# 0                                      BALTIC DIRTY TANKER TD9 70,000mt, Caribbean to US Gulf, Commodity Index, The Baltic Exchange
# 1                   Baltic Exchange Dirty Tanker TD21 Caribbean to US Gulf (50,000mt fuel oil), Commodity Spot, The Baltic Exchange
# 2                       Baltic Exchange Dirty Tanker TD9 TCE�Caribbean to US Gulf Time Charter, Commodity Spot, The Baltic Exchange
# 3  Baltic Exchange Dirty Tanker TD21 TCE Caribbean to US Gulf (50,000mt fuel oil) Time Charter, Commodity Spot, The Baltic Exchange
# 4                                    ELKA ELEFSIS, Gasoline; Medium, EUROPEAN PRODUCT CARRIERS, Caribbean Sea|Caribbean Tanker Zone
# 5                                      MINERVA JULIE, Medium, MINERVA MARINE INC, Baltic Sea|UK Continent Tanker Zone|Skaw Waypoint
# 6                                      ANDIAMO, Gasoline; Medium, PRIME TANKER MANAGEMENT INC, Baltic Sea|Baltic Tanker Zone|Latvia
# 7                                                       STAVANGER POSEIDON, Medium, Caribbean Sea|Caribbean Tanker Zone|Puerto Rico
# 8                           KALINKA, Gasoil / Heating Oil; Medium, SPRING MARINE MANAGEMENT SA, Caribbean Sea|Caribbean Tanker Zone
# 9                                                           CARONI PLAIN, Medium, METHANOL HOLDINGS, West Atlantic Ocean (Americas)
#
#               RIC
# 0           .BACG
# 1           .BACR
# 2       .BAAFRTD9
# 3      .BAAFRTD21
# 4  C}KM7309628067
# 5  C}KM7309494578
# 6  C}KM7309505681
# 7  C}KM7309873409
# 8  C}KM7309493434
# 9  C}KM7309495550

# %%
# Use a wildcard (*) to search for references to 'Covid*'.
response = rdp.Search.search(
    query = "Covid*",
    select = "DTSubjectName, DTSimpleType, DTSource, DTCharacteristics"
)
print(f'Matched a total of {response.data.total} documents')
response.data.df
# Out:
# Matched a total of 7089 documents
#   DTCharacteristics DTSource  \
# 0              <NA>     <NA>
# 1              <NA>     <NA>
# 2             Daily  Reuters
# 3             Daily  Reuters
# 4             Daily  Reuters
# 5             Daily  Reuters
# 6             Daily  Reuters
# 7             Daily  Reuters
# 8             Daily  Reuters
# 9             Daily  Reuters
#
#                                                                DTSubjectName  \
# 0                                                    Covidh Technologies Ltd
# 1                                                          Covidien Ventures
# 2                                Coronavirus (COVID-19), Total cases, Volume
# 3                                Coronavirus (COVID-19), Total cases, Volume
# 4                                Coronavirus (COVID-19), Total cases, Volume
# 5                                Coronavirus (COVID-19), Total cases, Volume
# 6  Middle East and North Africa, Coronavirus (COVID-19), Total cases, Volume
# 7                                Coronavirus (COVID-19), Total cases, Volume
# 8                                  Coronavirus (COVID-19), New cases, Volume
# 9                               Coronavirus (COVID-19), Active cases, Volume
#
#       DTSimpleType
# 0   Public Company
# 1  Private Company
# 2    Reuters Polls
# 3    Reuters Polls
# 4    Reuters Polls
# 5    Reuters Polls
# 6    Reuters Polls
# 7    Reuters Polls
# 8    Reuters Polls
# 9    Reuters Polls
