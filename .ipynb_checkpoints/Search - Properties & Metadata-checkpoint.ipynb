# %%
import refinitiv.dataplatform as rdp
import pandas as pd

rdp.open_desktop_session('Your API Key here')

# %%
pd.set_option('display.max_colwidth', 140)
rdp.__version__
# Out:
# '1.0.0a7.post1'

# %%
# Optionally override maximum dataframe rows
#pd.set_option('display.max_rows', 10000)

# %% [markdown]
# ### Properties / Metadata
# The document properties represent the fields that define the data elements you want to retrieve as well as the elements you choose to filter your results.  In addition, properties are at the heart of other Search parameters such as Navigation, Grouping, and Boosting.  There are hundreds of properties available for each View providing critical details needed to fulfill your searching requirements.
#
# In order for you to be successful at search, you will need to understand how to access the available properties, how to determine what values they contain and what they mean.

# %% [markdown]
# #### Metadata
# MetaData is a convenient service that allows you to list all available properties within a View.  To properly build a metadata list for inspection, you can issue the following:

# %%
# Specify the specific view
df = rdp.get_search_metadata(view = rdp.SearchViews.CommodityQuotes)
df
# Out:
#                                  Type  Searchable  Sortable  Navigable  \
# AAACurrencyBondBenchmarkChain  String       False     False      False
# AACurrencyBondBenchmarkChain   String       False     False      False
# ABSMBSBondsRIC                 String       False     False      False
# ActivityDate                     Date        True      True       True
# ACurrencyBondBenchmarkChain    String       False     False      False
# ...                               ...         ...       ...        ...
# WarrantsCount                  Double        True      True       True
# WarrantType                    String        True     False      False
# WarrantTypeName                String        True     False      False
# Wert                           String        True     False      False
# XMSAssetCategory               String        True     False      False
#
#                                Groupable  Exact  Symbol
# AAACurrencyBondBenchmarkChain      False  False   False
# AACurrencyBondBenchmarkChain       False  False   False
# ABSMBSBondsRIC                     False  False   False
# ActivityDate                       False  False   False
# ACurrencyBondBenchmarkChain        False  False   False
# ...                                  ...    ...     ...
# WarrantsCount                      False  False   False
# WarrantType                        False  False   False
# WarrantTypeName                    False  False   False
# Wert                               False  False    True
# XMSAssetCategory                   False  False   False
#
# [609 rows x 7 columns]

# %%
# Export metadata to a spreadsheet for easy viewing
df.to_excel("CommodityQuotes.xlsx")

# %% [markdown]
# #### Debugging (*_debugall*)
# While MetaData will help list all properties available within a View, all properties will not be available for use.  That is, depending on the type of search you perform, will determine which properties will be populated - not all will be.  This is where users can use a technique to list all available properties that are populated, for the specific search requested.

# %%
# Query for all documents with the company IBM defined
response=rdp.Search.search(
    query = "IBM",
    top = 1,    # Note: It is critical you select a top=1 because the amount of data returned is very large.
    select = "_debugall"
)
response.data.raw
# Out:
# {'Total': 41547,
#  'Hits': [{'meta': {'_id': '37036',
#     '_index': 'eikonsearch_organisation_1.132.0',
#     '_score': 2838774.0,
#     '_timestamp': 1607613753959,
#     '_timestamp_human': '2020-12-10T15:22:33.959Z',
#     '_version': 1607612267000},
#    'raw_source': {'RCSOrganisationTypeGenealogy': 'OT:1',
#     'SPsRatingOutlookX1XSPsRatingOutlookRank': 'SPI/NegativeX1X-1|SPI/NegativeX1X-1',
#     'RCSTRBCGenealogy': 'B:161\\B:171\\B:172\\B:173',
#     'IssuerID': '0x000019000050e3aa',
#     'SicSchemeCode': '8742',
#     'OfficersExist': True,
#     'IssuerBondsExist': True,
#     'CertificatesOfDepositCount': 0,
#     'MktCapCompanyUsd': 112977131737,
#     'TotalAssetsUsd': 152186000000,
#     'GEMPermID': '4295904307',
#     'SubjectBoost': 'firm',
#     'EEDBID': '14129',
#     'SigDevExist': True,
#     'SDCID': '3104001',
#     'TotalAssets': 152186000000,
#     'EstimatesExist': True,
#     'Ticker': 'IBM',
#     'CdsUltimateParentCount': 7,
#     'FilingsExist': True,
#     'CompanyOfficers': 'Senior Vice President:Erich Clementi |Senior Vice President:Diane J. Gherson |Senior Vice President:Martin J. Schroeter |Senior Vice President:John E. Kelly |Senior Vice President:Michelle H. Browdy |Chief Financial Officer:James J. Kavanaugh |Senior Vice President:Kenneth M. Keverian |Vice President:Robert F. Del Bene |Chairman:Virginia M. Rometty',
#     'CompositeSearchAllZh': '公司',
#     'CommonNameJaHani': 'インターナショナル･ビジネス･マシーンズ･コーポレーション',
#     'RatingOutlookRank': 'MDL/0|MDL/0|MRS/0',
#     'CurrentRatio': 1.019071,
#     'UltimateParentOrganisationOrgid': '18228',
#     'PreviousNames': 'COMPUTING-TABULATING-RECORDING-CO.|1911-06-16|1924-02-14',
#     'TRBCHierarchicalCode': '5720101010',
#     'NetProfit': 9431000000,
#     'PrimaryIssuePILC': '144477',
#     'IsExchange': False,
#     'RCSOriginalAccountsCurrencyLeafML': 'ja 米ドル|zh-Hans 美元|zh-Hant 美元',
#     'DTSubjectNameJaHani': 'インターナショナル･ビジネス･マシーンズ･コーポレーション',
#     'RCSOriginalAccountsCurrencyLeaf': 'US Dollar',
#     'SPsRatingScopeRank': 'SIS/1|SSU/1|SIS/2|SSU/2|SPI/2|SMU/1|SCP/2|SPI/1|SMU/2',
#     'CompositeSearchAllJa': '事業法人',
#     'IsMainCompanyFiling': True,
#     'RatingsScope': [{'Agency': 'FTC',
#       'RatingType': 'FDL',
#       'CurrentRatingRank': 98,
#       'CurrentRatingDate': '2019-07-01T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'RatingScope': 'F'},
#      {'Agency': 'EGJ',
#       'RatingType': 'EJC',
#       'CurrentRatingRank': 2,
#       'CurrentRatingDate': '2018-11-02T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'RatingScope': 'D'},
#      {'Agency': 'MDY',
#       'RatingType': 'MCP',
#       'CurrentRatingRank': 1,
#       'CurrentRatingDate': '2016-03-30T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'RatingScope': 'D'},
#      {'Agency': 'MDY',
#       'RatingType': 'MDL',
#       'CurrentRatingRank': 7,
#       'CurrentRatingDate': '2019-07-09T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'OutlookRank': 0,
#       'RatingScope': 'F',
#       'Outlook': 'Stable'},
#      {'Agency': 'MDY',
#       'RatingType': 'MIS',
#       'CurrentRatingRank': 7,
#       'CurrentRatingDate': '2019-07-09T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'RatingScope': 'D'},
#      {'Agency': 'EGJ',
#       'RatingType': 'EJC',
#       'CurrentRatingRank': 2,
#       'CurrentRatingDate': '2019-01-30T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'RatingScope': 'F'},
#      {'Agency': 'MDY',
#       'RatingType': 'MIS',
#       'CurrentRatingRank': 7,
#       'CurrentRatingDate': '2019-07-09T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'RatingScope': 'F'},
#      {'Agency': 'FTC',
#       'RatingType': 'FCP',
#       'CurrentRatingRank': 98,
#       'CurrentRatingDate': '2019-07-01T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'RatingScope': 'F'},
#      {'Agency': 'MDY',
#       'RatingType': 'MDL',
#       'CurrentRatingRank': 7,
#       'CurrentRatingDate': '2019-07-09T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'OutlookRank': 0,
#       'RatingScope': 'D',
#       'Outlook': 'Stable'},
#      {'Agency': 'MDY',
#       'RatingType': 'MSU',
#       'CurrentRatingRank': 7,
#       'CurrentRatingDate': '2019-07-09T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'RatingScope': 'F'},
#      {'Agency': 'FTC',
#       'RatingType': 'FSS',
#       'CurrentRatingRank': 98,
#       'CurrentRatingDate': '2007-05-30T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'RatingScope': 'F'},
#      {'Agency': 'FTC',
#       'RatingType': 'FSU',
#       'CurrentRatingRank': 7,
#       'CurrentRatingDate': '2018-10-30T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'y',
#       'RatingScope': 'F'},
#      {'Agency': 'MDY',
#       'RatingType': 'MSU',
#       'CurrentRatingRank': 7,
#       'CurrentRatingDate': '2019-07-09T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'RatingScope': 'D'},
#      {'Agency': 'MDY',
#       'RatingType': 'MCP',
#       'CurrentRatingRank': 1,
#       'CurrentRatingDate': '1994-10-19T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'RatingScope': 'F'},
#      {'Agency': 'FTC',
#       'RatingType': 'FMU',
#       'CurrentRatingRank': 98,
#       'CurrentRatingDate': '2015-07-15T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'RatingScope': 'D'},
#      {'Agency': 'FTC',
#       'RatingType': 'FDT',
#       'CurrentRatingRank': 2,
#       'CurrentRatingDate': '2018-10-30T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'y',
#       'RatingScope': 'D'},
#      {'Agency': 'MDY',
#       'RatingType': 'MMU',
#       'CurrentRatingRank': 98,
#       'CurrentRatingDate': '2016-11-18T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'RatingScope': 'F'},
#      {'Agency': 'FTC',
#       'RatingType': 'FSU',
#       'CurrentRatingRank': 98,
#       'CurrentRatingDate': '2019-07-01T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'RatingScope': 'D'},
#      {'Agency': 'MDY',
#       'RatingType': 'MRS',
#       'CurrentRatingRank': 1,
#       'CurrentRatingDate': '2019-07-09T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'OutlookRank': 0,
#       'RatingScope': 'F',
#       'Outlook': 'Stable'},
#      {'Agency': 'EGJ',
#       'RatingType': 'EJU',
#       'CurrentRatingRank': 8,
#       'CurrentRatingDate': '2020-04-29T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'RatingScope': 'F'},
#      {'Agency': 'EGJ',
#       'RatingType': 'EJU',
#       'CurrentRatingRank': 8,
#       'CurrentRatingDate': '2020-04-29T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'RatingScope': 'D'},
#      {'Agency': 'FTC',
#       'RatingType': 'FDS',
#       'CurrentRatingRank': 98,
#       'CurrentRatingDate': '2019-07-01T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'RatingScope': 'F'},
#      {'Agency': 'FTC',
#       'RatingType': 'FIS',
#       'CurrentRatingRank': 98,
#       'CurrentRatingDate': '2005-10-05T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'RatingScope': 'F'},
#      {'Agency': 'MDY',
#       'RatingType': 'MMU',
#       'CurrentRatingRank': 98,
#       'CurrentRatingDate': '2016-11-18T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'RatingScope': 'D'},
#      {'Agency': 'FTC',
#       'RatingType': 'FCP',
#       'CurrentRatingRank': 2,
#       'CurrentRatingDate': '2007-05-30T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'y',
#       'RatingScope': 'D'}],
#     'RatingType': 'Issuer/FTC/FDL|Issuer/EGJ/EJC|Issuer/MDY/MCP|Issuer/MDY/MDL|Issuer/MDY/MIS|Issuer/EGJ/EJC|Issuer/MDY/MIS|Issuer/FTC/FCP|Issuer/MDY/MDL|Issuer/MDY/MSU|Issuer/FTC/FSS|Issuer/FTC/FSU|Issuer/MDY/MSU|Issuer/MDY/MCP|Issuer/FTC/FMU|Issuer/FTC/FDT|Issuer/MDY/MMU|Issuer/FTC/FSU|Issuer/MDY/MRS|Issuer/EGJ/EJU|Issuer/EGJ/EJU|Issuer/FTC/FDS|Issuer/FTC/FIS|Issuer/MDY/MMU|Issuer/FTC/FCP',
#     'SPsRatingNameX1XSPsRatingType': "Issuer/Standard & Poor's Bond Rating ServicesX1XS&P/S&P Short-term Issuer Credit RatingX1XSIS|Issuer/Standard & Poor's Bond Rating ServicesX1XS&P/S&P Senior UnsecuredX1XSSU|Issuer/Standard & Poor's Bond Rating ServicesX1XS&P/S&P Short-term Issuer Credit RatingX1XSIS|Issuer/Standard & Poor's Bond Rating ServicesX1XS&P/S&P Senior UnsecuredX1XSSU|Issuer/Standard & Poor's Bond Rating ServicesX1XS&P/S&P Long-term Issuer RatingX1XSPI|Issuer/Standard & Poor's Bond Rating ServicesX1XS&P/S&P Long-term Senior Unsecured MTN RatingX1XSMU|Issuer/Standard & Poor's Bond Rating ServicesX1XS&P/S&P Commercial PaperX1XSCP|Issuer/Standard & Poor's Bond Rating ServicesX1XS&P/S&P Long-term Issuer RatingX1XSPI|Issuer/Standard & Poor's Bond Rating ServicesX1XS&P/S&P Long-term Senior Unsecured MTN RatingX1XSMU",
#     'AddressLine1': '1 New Orchard Rd',
#     'RCSCountryHeadquarters': 'G:6J',
#     'ParentCompanyNDAPI': '37036',
#     'GicsName': 'Information Technology|Information Technology/Software & Services|Information Technology/Software & Services/IT Services|Information Technology/Software & Services/IT Services/IT Consulting & Other Services',
#     'InvestmentCertificateCount': 0,
#     'SuggestPhrase': 'internatnl intl intrnl internatnl intl intrnl | it services & consulting (nec) organisation corporation listed |big blue|guo ji shang ye ji qi gong si|guo ji shang yong ji qi|ibm|intanashonaru bijinesu mashinzu|international business machines|software artistry inc|unison software inc|international business machines corp|international business machines corporation|never',
#     'OAOrgSubTypeName': 'Company',
#     'ListingStatusName': 'Listed',
#     'RCSCountryHeadquartersLeafML': 'ja 米国|zh-Hans 美国|zh-Hant 美國|es Estados Unidos|fr États Unis|ko 미국|ru США',
#     'RCSTRBCName': 'Technology\\Software & IT Services\\Software & IT Services\\IT Services & Consulting',
#     'RCSOrganisationTypeNameML': 'ja 事業法人|zh-Hans 公司|zh-Hant 公司',
#     'LongTermDebt': 54102000000,
#     'RCSTRBC2012NameML': 'ja テクノロジー\\ソフトウェア & IT サービス\\ソフトウェア & IT サービス\\IT サービス & コンサルティング\\IT サービス & コンサルティング (その他)|zh-Hans 技术\\软件及信息技术服务\\软件及信息技术服务\\信息技术服务及咨询\\IT 服务及咨询 (NEC)|zh-Hant 技術\\軟體及信息技術服務\\軟體及信息技術服務\\信息技術服務及諮詢\\IT 服務及諮詢 (NEC)',
#     'SPsRatingX1XSPsRatingScopeRank': 'SIS/DX1X1|SSU/DX1X1|SIS/FX1X2|SSU/FX1X2|SPI/FX1X2|SMU/DX1X1|SCP/FX1X2|SPI/DX1X1|SMU/FX1X2',
#     'Ev': 167152131737,
#     'PrimaryRICRCSAssetCategory': 'A:1L',
#     'RCSFilingCurrencyName': 'US Dollar',
#     'UltimateParentOrganisationName': 'International Business Machines Corp',
#     'BusinessDescription': 'International Business Machines Corporation (IBM) is a technology company. The Company operates through five segments: Cognitive Solutions, Global Business Services (GBS), Technology Services & Cloud Platforms, Systems and Global Financing. The Cognitive Solutions segment delivers a spectrum of capabilities, from descriptive, predictive and prescriptive analytics to cognitive systems. Cognitive Solutions includes Watson, a cognitive computing platform that has the ability to interact in natural language, process big data, and learn from interactions with people and computers. The GBS segment provides clients with consulting, application management services and global process services. The Technology Services & Cloud Platforms segment provides information technology infrastructure services. The Systems segment provides clients with infrastructure technologies. The Global Financing segment includes client financing, commercial financing, and remanufacturing and remarketing.',
#     'RCSCountryOfIncorporationGenealogy': 'M:DQ\\G:AM\\G:6J|M:DQ\\G:AN\\G:6J|M:DH\\G:4\\G:9\\G:6J|M:DQ\\G:AQ\\G:6J|M:DQ\\G:AR\\G:6J|M:DQ\\G:AS\\G:6J|M:A9\\G:6J|M:DQ\\G:B9\\G:6J|M:1M2\\G:3U8\\G:3U9\\G:6J|M:DQ\\G:CX\\G:6J|M:DQ\\G:DE\\G:6J',
#     'TRBCPrimaryCode': '173',
#     'CommonNameJaKana': 'インターナショナルビジネスマシーンズコーポレーション',
#     'RatingScopeRank': 'FDL/2|EJC/1|MCP/1|MDL/2|MIS/1|EJC/2|MIS/2|FCP/2|MDL/1|MSU/2|FSS/2|FSU/2|MSU/1|MCP/2|FMU/1|FDT/1|MMU/2|FSU/1|MRS/2|EJU/2|EJU/1|FDS/2|FIS/2|MMU/1|FCP/1',
#     'LegalNameJaHani': 'インターナショナル･ビジネス･マシーンズ･コーポレーション',
#     'OpMargin': 13.896846,
#     'SearchAllCategory': 'Companies/Issuers',
#     'RCSOriginalAccountsCurrency': 'C:6',
#     'RCSTRBC2012': 'B:1790',
#     'SicScheme': 'Engineering and management services/Management and Public Relations/Management Consulting Services',
#     'SearchTypeBase': 1,
#     'RatingX1XRatingScopeRank': 'FDL/FX1X2|EJC/DX1X1|MCP/DX1X1|MDL/FX1X2|MIS/DX1X1|EJC/FX1X2|MIS/FX1X2|FCP/FX1X2|MDL/DX1X1|MSU/FX1X2|FSS/FX1X2|FSU/FX1X2|MSU/DX1X1|MCP/FX1X2|FMU/DX1X1|FDT/DX1X1|MMU/FX1X2|FSU/DX1X1|MRS/FX1X2|EJU/FX1X2|EJU/DX1X1|FDS/FX1X2|FIS/FX1X2|MMU/DX1X1|FCP/DX1X1',
#     'InterestCover': 7.434813,
#     'CommonName': 'International Business Machines Corp',
#     'OAOrgTypeName': 'Business Organization',
#     'NAVPrimaryRIC': '<a:Rship name="x" xmlns:a="http://www.reuters.com/ns/2007/10/31/webservices/SearchAndNavigation_1/NavCommonResponse_1"><a:Entity><a:Prop name="RIC" value="IBM"/><a:Req value="62" scheme="IDN"/><a:Req value="4017" scheme="IDN"/></a:Entity></a:Rship>',
#     'MainFilingType': 'CONSOLIDATED',
#     'OrganizationWebsite': 'https://www.ibm.com/',
#     'EquityInstrumentsCount': 4,
#     'UltimateParentCompanyOAPermID': '4295904307',
#     'SPsRatingPreliminary': 'SIS/n|SSU/n|SIS/n|SSU/n|SPI/n|SMU/n|SCP/n|SPI/n|SMU/n',
#     'PrimaryRICCUSIP': '459200101',
#     'DTSubjectNameJaKana': 'インターナショナルビジネスマシーンズコーポレーション',
#     'RCSFilingCountryLeaf': 'United States',
#     'MainFilingCommonName': 'International Business Machines Corp.',
#     'DocumentsExist': True,
#     'RCSTRBCLeaf': 'IT Services & Consulting',
#     'ShortTermDebt': 8797000000,
#     'TRBC2012PrimaryCode': '1790',
#     'ParentCompanyOAPermID': '4295904307',
#     'AddressCity': 'ARMONK',
#     'SalesToWorkingCap': 13.257776,
#     'IndicesCount': 0,
#     'RbssSchemeCode': '1790',
#     'Filename': 'Update_CL3_US2P_G1.4_Organisation_0012281_20201210_145747_A_incr_wi_000764.xml.xz',
#     'PretaxProfitUsd': 10166000000,
#     'MainRepnoAttributes': '<a:Rship name="x" xmlns:a="http://www.reuters.com/ns/2007/10/31/webservices/SearchAndNavigation_1/NavCommonResponse_1"><a:Entity><a:Prop name="ActiveEstimatesExist" value="Y"/><a:Prop name="BusinessIntelligenceExists" value="Y"/><a:Prop name="FundamentalsExist" value="Y"/><a:Prop name="EstimatesExist" value="Y"/><a:Prop name="SigDevExist" value="Y"/><a:Prop name="OfficersExist" value="Y"/><a:Prop name="Repno" value="4741N"/><a:Prop name="CommonName" value="International Business Machines Corp."/><a:Prop name="Type" value="CONSOLIDATED"/><a:Prop name="IsMainIssueFiling" value="Y"/><a:Prop name="IsMainCompanyFiling" value="Y"/><a:Prop name="RCSCurrencyName" value="US Dollar"/><a:Prop name="RCSCountryLeaf" value="United States"/></a:Entity></a:Rship>',
#     'RevenueUsd': 77147000000,
#     'IsPublic': True,
#     'OwnershipExists': True,
#     'OAPermID': '4295904307',
#     'Ebit': 10721000000,
#     'DebtToEquity': 6.295331,
#     'CompanyDataStreamID': '003671',
#     'IsTRACEEligible': True,
#     'InsertDateTime': '2020-11-23T13:32:26.000Z',
#     'SynonymDescriptiveName': 'internatnl INTL intrnl internatnl INTL intrnl',
#     'CDS5YSuperRIC': '<a:Rship name="x" xmlns:a="http://www.reuters.com/ns/2007/10/31/webservices/SearchAndNavigation_1/NavCommonResponse_1"><a:Entity rank="1"><a:Prop name="RIC" value="IBM5YUSAX="/><a:Prop name="DisplayName" value="IBM" lang="en"/><a:Req value="6995" scheme="IDN"/></a:Entity></a:Rship>',
#     'RCSFilingCountryNameML': 'ja 国際機関\\\\米国|zh-Hans 国家分组\\\\美国|zh-Hant 國家分組\\\\美國|es \\\\Estados Unidos|fr \\\\États Unis|ko \\\\미국|ru \\\\США|ja 国際機関\\\\米国|zh-Hans 国家分组\\北大西洋公约组织\\美国|zh-Hant 國家分組\\北大西洋公約組織\\美國|es \\\\Estados Unidos|fr \\\\États Unis|ko \\\\미국|ru \\\\США|es Continentes/regiones\\Continente Americano\\Norteamérica\\Estados Unidos|fr Continents/Régions\\Amérique\\Amérique du Nord\\États Unis|ja 大陸 / 地域\\北米 & 中南米\\北米\\米国|ru Континенты/регионы\\Америка\\Северная Америка\\США|zh-Hans 大陆/地区\\美洲\\北美\\美国|zh-Hant 大陸/地區\\美洲\\北美\\美國|ko \\미주\\북아메리카\\미국|ja 国際機関\\\\米国|zh-Hans 国家分组\\亚太经济合作组织\\美国|zh-Hant 國家分組\\亞太經濟合作組織\\美國|es \\\\Estados Unidos|fr \\\\États Unis|ko \\\\미국|ru \\\\США|ja 国際機関\\\\米国|zh-Hans 国家分组\\经济合作与发展组织\\美国|zh-Hant 國家分組\\經濟合作與發展組織\\美國|es \\\\Estados Unidos|fr \\\\États Unis|ko \\\\미국|ru \\\\США|ja 国際機関\\\\米国|zh-Hans 国家分组\\\\美国|zh-Hant 國家分組\\\\美國|es \\\\Estados Unidos|fr \\\\États Unis|ko \\\\미국|ru \\\\США|ja 国\\米国|zh-Hans 国家/地区\\美国|zh-Hant 國家/地區\\美國|es \\Estados Unidos|fr \\États Unis|ko \\미국|ru \\США|ja 国際機関\\\\米国|zh-Hans 国家分组\\\\美国|zh-Hant 國家分組\\\\美國|es \\\\Estados Unidos|fr \\\\États Unis|ko \\\\미국|ru \\\\США|ja FRUC 地域\\グローバル\\北米\\米国|zh-Hans FRUC 区域\\全球\\北美\\美国|zh-Hant FRUC 區域\\全球\\北美\\美國|es \\\\\\Estados Unidos|fr \\\\\\États Unis|ko \\\\\\미국|ru \\\\\\США|ja 国際機関\\\\米国|zh-Hans 国家分组\\G10 集团\\美国|zh-Hant 國家分組\\G10 集團\\美國|es \\\\Estados Unidos|fr \\\\États Unis|ko \\\\미국|ru \\\\США|ja 国際機関\\北アフリカ (EIU)\\米国|zh-Hans 国家分组\\北美 (EIU)\\美国|zh-Hant 國家分組\\北美 (EIU)\\美國|es \\\\Estados Unidos|fr \\\\États Unis|ko \\\\미국|ru \\\\США',
#     'MnaParentTargetCount': 0,
#     'SectorIndices': '<a:Rship name="x" xmlns:a="http://www.reuters.com/ns/2007/10/31/webservices/SearchAndNavigation_1/NavCommonResponse_1"><a:Entity rank="1"><a:Prop name="DisplayName" value="DOW JONES TECHNOLOGY NDX" lang="en"/><a:Prop name="RIC" value=".DJUSTC"/><a:Req value="9822" scheme="IDN"/><a:Req value="4017" scheme="IDN"/></a:Entity><a:Entity rank="2"><a:Prop name="DisplayName" value="S&amp;P 500 IT Consulting&amp;Other Serv(SI)" lang="en"/><a:Prop name="RIC" value=".SPLRCTKCS"/><a:Req value="5185" scheme="IDN"/><a:Req value="5775" scheme="IDN"/></a:Entity><a:Entity rank="3"><a:Prop name="DisplayName" value="S&amp;P 500 IT Services (Industry)" lang="en"/><a:Prop name="RIC" value=".SPLRCITCS"/><a:Req value="5185" scheme="IDN"/><a:Req value="5775" scheme="IDN"/></a:Entity><a:Entity rank="4"><a:Prop name="DisplayName" value="S&amp;P 500 Software &amp; Services (IG)" lang="en"/><a:Prop name="RIC" value=".SPLRCIS"/><a:Req value="5185" scheme="IDN"/><a:Req value="5775" scheme="IDN"/></a:Entity><a:Entity rank="5"><a:Prop name="DisplayName" value="标普信息技术指数" lang="zh-Hans"/><a:Prop name="RIC" value=".SPLRCT"/><a:Req value="5185" scheme="IDN"/><a:Req value="5775" scheme="IDN"/></a:Entity><a:Entity rank="6"><a:Prop name="DisplayName" value="S&amp;P 500種 情報技術セクター指数" lang="ja-Hani"/><a:Prop name="RIC" value=".SPLRCT"/><a:Req value="5185" scheme="IDN"/><a:Req value="5775" scheme="IDN"/></a:Entity><a:Entity rank="7"><a:Prop name="DisplayName" value="S&amp;P 500 Information Tech(Sector)" lang="en"/><a:Prop name="RIC" value=".SPLRCT"/><a:Req value="5185" scheme="IDN"/><a:Req value="5775" scheme="IDN"/></a:Entity><a:Entity rank="8"><a:Prop name="DisplayName" value="S&amp;P Composite 1500 Software&amp;Serv(IG)" lang="en"/><a:Prop name="RIC" value=".SPCOMIS"/><a:Req value="5185" scheme="IDN"/><a:Req value="5775" scheme="IDN"/></a:Entity><a:Entity rank="9"><a:Prop name="DisplayName" value="S&amp;P 1500 IT Services (Ind)" lang="en"/><a:Prop name="RIC" value=".SPCOMITCS"/><a:Req value="5185" scheme="IDN"/><a:Req value="5775" scheme="IDN"/></a:Entity><a:Entity rank="10"><a:Prop name="DisplayName" value="S&amp;P 1500 Info Technology (Sector)" lang="en"/><a:Prop name="RIC" value=".SPCOMT"/><a:Req value="5185" scheme="IDN"/><a:Req value="5775" scheme="IDN"/></a:Entity><a:Entity rank="11"><a:Prop name="DisplayName" value="S&amp;P 1500 ITConsulting&amp;Other Serv(SI)" lang="en"/><a:Prop name="RIC" value=".SPCOMTKCS"/><a:Req value="5185" scheme="IDN"/><a:Req value="5775" scheme="IDN"/></a:Entity><a:Entity rank="12"><a:Prop name="DisplayName" value="ARCA COMPUT TECH" lang="en"/><a:Prop name="RIC" value=".XCI"/><a:Req value="6465" scheme="IDN"/><a:Req value="5053" scheme="IDN"/></a:Entity><a:Entity rank="13"><a:Prop name="DisplayName" value="Refinitiv United States Technology Price Return Index" lang="en"/><a:Prop name="RIC" value=".TRXFLDUSPTEC"/><a:Req value="7642" scheme="IDN"/></a:Entity><a:Entity rank="14"><a:Prop name="DisplayName" value="Refinitiv North America Technology Price Return Index" lang="en"/><a:Prop name="RIC" value=".TRXFLDNAPUTEC"/><a:Req value="7642" scheme="IDN"/></a:Entity><a:Entity rank="15"><a:Prop name="DisplayName" value="Refinitiv NAFTA Technology Price Return Index" lang="en"/><a:Prop name="RIC" value=".TRXFLDNFPUTEC"/><a:Req value="7642" scheme="IDN"/></a:Entity><a:Entity rank="16"><a:Prop name="DisplayName" value="Refinitiv G7 Technology Price Return Index" lang="en"/><a:Prop name="RIC" value=".TRXFLDG7PUTEC"/><a:Req value="3112" scheme="IDN"/></a:Entity><a:Entity rank="17"><a:Prop name="DisplayName" value="Refinitiv Global Technology Price Return Index" lang="en"/><a:Prop name="RIC" value=".TRXFLDGLPUTEC"/><a:Req value="3112" scheme="IDN"/></a:Entity></a:Rship>',
#     'OpProfitInterim': 1845000000,
#     'Source': 'NDA',
#     'DisclosureIDs': 'I510600000',
#     'RCSFilingCountry': 'G:6J',
#     'GeneralAliasNameZhHans': '国际商业机器公司|国际商用机器',
#     'RCSTRBCNameML': 'ja テクノロジー\\ソフトウェア & IT サービス\\ソフトウェア & IT サービス\\IT サービス & コンサルティング|zh-Hans 技术\\软件及信息技术服务\\软件及信息技术服务\\信息技术服务及咨询|zh-Hant 技術\\軟體及信息技術服務\\軟體及信息技術服務\\信息技術服務及諮詢',
#     'SPsRatingX1XSPsRatingRankForeign': 'SIS/A-1X1X2|SSU/AX1X11|SPI/AX1X6|SCP/A-1X1X2|SMU/NRX1X0',
#     'CalaisAlias': "International Business Machines Corporation|IBM Corporation|INTL Business Machines Corp|International Business machines|IBM Corp.|International Business Machines|International Business Machines (IBM)|Intl Business Machines Corp|International Business Machines Corp|INTL|International Business|Software, Inc.|Business Machines Corp|International Business Machines Corp.|Unison|IBM Corp|INTERNATIONAL BUSINESS MACHINES CORP|International Business Machines Corporation (IBM)|@IBM|IBM's|IBM|International|INTERNATIONAL BUSINESS MACHINES|IBM Inc|International Business Machines Corp's (IBM|INTERNATIONAL BUSINESS MACHINES CORPORATION|International Business Machines Corp (IBM)|International Business Machines Corp .|International Business Machines Corp  .|IBM CORP|Big Ag",
#     'GeneralAliasName': 'Big Blue|Guo Ji Shang Ye Ji Qi Gong Si|Guo Ji Shang Yong Ji Qi|IBM|Intanashonaru Bijinesu Mashinzu|International Business Machines|Software Artistry Inc|Unison Software Inc',
#     'Gics': 'Information Technology/Software & Services/IT Services/IT Consulting & Other Services',
#     'SPsRatings': '<EntityList xmlns="uri://GenericEntityContainer_2.xsd"><Entity name="Rating"><Property name="Agency" value="Standard &amp; Poor&apos;s Bond Rating Services"/><Property name="RatingType" value="S&amp;P Short-term Issuer Credit Rating"/><Property name="RatingTypeCode" value="SIS"/><Property name="CurrentRating" value="A-1"/><Property name="CurrentRatingDate" value="2017-05-05"/><Property name="Preliminary" value="n"/><Property name="Solicited" value="n"/><Property name="RatingScope" value="D"/></Entity><Entity name="Rating"><Property name="Agency" value="Standard &amp; Poor&apos;s Bond Rating Services"/><Property name="RatingType" value="S&amp;P Senior Unsecured"/><Property name="RatingTypeCode" value="SSU"/><Property name="CurrentRating" value="A"/><Property name="CurrentRatingDate" value="2018-10-29"/><Property name="Preliminary" value="n"/><Property name="Solicited" value="n"/><Property name="RatingScope" value="D"/></Entity><Entity name="Rating"><Property name="Agency" value="Standard &amp; Poor&apos;s Bond Rating Services"/><Property name="RatingType" value="S&amp;P Short-term Issuer Credit Rating"/><Property name="RatingTypeCode" value="SIS"/><Property name="CurrentRating" value="A-1"/><Property name="CurrentRatingDate" value="2017-05-05"/><Property name="Preliminary" value="n"/><Property name="Solicited" value="n"/><Property name="RatingScope" value="F"/></Entity><Entity name="Rating"><Property name="Agency" value="Standard &amp; Poor&apos;s Bond Rating Services"/><Property name="RatingType" value="S&amp;P Senior Unsecured"/><Property name="RatingTypeCode" value="SSU"/><Property name="CurrentRating" value="A"/><Property name="CurrentRatingDate" value="2018-10-29"/><Property name="Preliminary" value="n"/><Property name="Solicited" value="n"/><Property name="RatingScope" value="F"/></Entity><Entity name="Rating"><Property name="Agency" value="Standard &amp; Poor&apos;s Bond Rating Services"/><Property name="RatingType" value="S&amp;P Long-term Issuer Rating"/><Property name="RatingTypeCode" value="SPI"/><Property name="CurrentRating" value="A"/><Property name="CurrentRatingDate" value="2018-10-29"/><Property name="Preliminary" value="n"/><Property name="Solicited" value="n"/><Property name="Outlook" value="Negative"/><Property name="RatingScope" value="F"/></Entity><Entity name="Rating"><Property name="Agency" value="Standard &amp; Poor&apos;s Bond Rating Services"/><Property name="RatingType" value="S&amp;P Long-term Senior Unsecured MTN Rating"/><Property name="RatingTypeCode" value="SMU"/><Property name="CurrentRating" value="A"/><Property name="CurrentRatingDate" value="2018-10-29"/><Property name="Preliminary" value="n"/><Property name="Solicited" value="n"/><Property name="RatingScope" value="D"/></Entity><Entity name="Rating"><Property name="Agency" value="Standard &amp; Poor&apos;s Bond Rating Services"/><Property name="RatingType" value="S&amp;P Commercial Paper"/><Property name="RatingTypeCode" value="SCP"/><Property name="CurrentRating" value="A-1"/><Property name="CurrentRatingDate" value="2017-05-05"/><Property name="Preliminary" value="n"/><Property name="Solicited" value="n"/><Property name="RatingScope" value="F"/></Entity><Entity name="Rating"><Property name="Agency" value="Standard &amp; Poor&apos;s Bond Rating Services"/><Property name="RatingType" value="S&amp;P Long-term Issuer Rating"/><Property name="RatingTypeCode" value="SPI"/><Property name="CurrentRating" value="A"/><Property name="CurrentRatingDate" value="2018-10-29"/><Property name="Preliminary" value="n"/><Property name="Solicited" value="n"/><Property name="Outlook" value="Negative"/><Property name="RatingScope" value="D"/></Entity><Entity name="Rating"><Property name="Agency" value="Standard &amp; Poor&apos;s Bond Rating Services"/><Property name="RatingType" value="S&amp;P Long-term Senior Unsecured MTN Rating"/><Property name="RatingTypeCode" value="SMU"/><Property name="CurrentRating" value="NR"/><Property name="Current ...
#     'LiquidityRIC': '0#IBM=',
#     'DocumentTitleJaHira': 'いんたーなしょなるびじねすましーんずこーぽれーしょん, Public Company',
#     'RCSTRBC2012Name': 'Technology\\Software & IT Services\\Software & IT Services\\IT Services & Consulting\\IT Services & Consulting (NEC)',
#     'MnaTargetCount': 0,
#     'TotalLiabilities': 131201000000,
#     'CompositeSymbolOnly': '18228',
#     'RCSPartyCountry': 'G:6J',
#     'IsLegacySearchContent': True,
#     'RbssScheme': 'IT Services & Consulting - NEC',
#     'PreferenceSharesCount': 9,
#     'RCSFilingCountryName': 'Country Grouping\\G7\\United States|Country Grouping\\NATO\\United States|Continent / Region\\Americas\\North America\\United States|Country Grouping\\APEC\\United States|Country Grouping\\OECD\\United States|Country Grouping\\G8\\United States|Country\\United States|Country Grouping\\G20\\United States|FRUC Regions\\Global\\North America\\United States|Country Grouping\\G10\\United States|Country Grouping\\North America (EIU)\\United States',
#     'IssuersTRCDSCurveRIC': '<a:Rship name="x" xmlns:a="http://www.reuters.com/ns/2007/10/31/webservices/SearchAndNavigation_1/NavCommonResponse_1"><a:Entity rank="1"><a:Prop name="RIC" value="0#IBMUSAXRBMK="/><a:Prop name="DisplayName" value="IBM" lang="en"/><a:Req value="7674" scheme="IDN"/></a:Entity></a:Rship>',
#     'PrimaryRIC': 'IBM',
#     'CommercialPaperCount': 0,
#     'RCSCountryHeadquartersName': 'Country Grouping\\G7\\United States|Country Grouping\\NATO\\United States|Continent / Region\\Americas\\North America\\United States|Country Grouping\\APEC\\United States|Country Grouping\\OECD\\United States|Country Grouping\\G8\\United States|Country\\United States|Country Grouping\\G20\\United States|FRUC Regions\\Global\\North America\\United States|Country Grouping\\G10\\United States|Country Grouping\\North America (EIU)\\United States',
#     'SPsRatingRank': 'SIS/2|SSU/11|SIS/2|SSU/11|SPI/6|SMU/11|SCP/2|SPI/6|SMU/0',
#     'SynonymDescriptiveNameJa': 'インタナショナル コーポレイション インタナショナル コーポレイション',
#     'DTSubjectName': 'International Business Machines Corp',
#     'CostOfSales': -40659000000,
#     'RegistrationAuthorityName': 'New York State Department Of State',
#     'RevenueGrowth5Y': -3.625805,
#     'GicsCode': '45102010',
#     'CdsCount': 463,
#     'DebtToAssets': 0.86211,
#     'UltimateParentCompanyNDAPI': '37036',
#     'RatingPreliminary': 'FDL/n|EJC/n|MCP/n|MDL/n|MIS/n|EJC/n|MIS/n|FCP/n|MDL/n|MSU/n|FSS/n|FSU/n|MSU/n|MCP/n|FMU/n|FDT/n|MMU/n|FSU/n|MRS/n|EJU/n|EJU/n|FDS/n|FIS/n|MMU/n|FCP/n',
#     'TRBCHierarchicalShortCode': '572211',
#     'FundsCount': 0,
#     'OriginalAccountsCurrency': 'USD',
#     'FitchIssuerRating': 'WD',
#     'LegalNameJaHira': 'いんたーなしょなるびじねすましーんずこーぽれーしょん',
#     'RCSOrganisationType': 'OT:1',
#     'CIK': '0000051143',
#     'RCSOrganisationSubType': 'OAOST:COR',
#     'Red6Code': '49EB20',
#     'PEBackedStatus': 'Never',
#     'RegistrationNumber': '30059',
#     'PrimaryRICPI': '1097326',
#     'RatingX1XRatingRankForeign': 'FDL/WDX1X98|MDL/A2X1X7|EJC/A1X1X2|MIS/A2X1X7|FCP/WDX1X98|MSU/A2X1X7|FSS/WDX1X98|FSU/AX1X7|MCP/P-1X1X1|MMU/WRX1X98|MRS/P-1X1X1|EJU/BBB+X1X8|FDS/WDX1X98|FIS/WDX1X98',
#     'RegistrationAuthorityOrganizationID': '5000064525',
#     'RatingX1XRatingRankDomestic': 'EJC/A1X1X2|MCP/P-1X1X1|MIS/A2X1X7|MDL/A2X1X7|MSU/A2X1X7|FMU/WDX1X98|FDT/F1X1X2|FSU/WDX1X98|EJU/BBB+X1X8|MMU/WRX1X98|FCP/F1X1X2',
#     'TotalOperatingIncome': 77147000000,
#     'SPsRatingOutlookRank': 'SPI/-1|SPI/-1',
#     'PrimaryRICRICUsageCount': 6658,
#     'RatingsExist': True,
#     'Orgid': '18228',
#     'NumberOfEmployees': 352600,
#     'SubsidiariesCount': 199,
#     'FundamentalsExist': True,
#     'IsActive': True,
#     'DTSubjectNameJaHira': 'いんたーなしょなるびじねすましーんずこーぽれーしょん',
#     'InterimNetIncome': 1698000000,
#     'OAOrgSubType': 'COR',
#     'SPIssuerRating': 'A',
#     'BusinessEntity': 'ORGANISATION',
#     'DEBUGBATCH': 'Update_CL3_US2P_G1.4_Organisation_0012281_20201210_145747_A_incr_wi_000764.xml.xz',
#     'RCSTRBCLeafML': 'ja IT サービス & コンサルティング|zh-Hans 信息技术服务及咨询|zh-Hant 信息技術服務及諮詢',
#     'OrganisationTypeName': 'Corporation',
#     'CompositeIdentifyingCode': 'VGRQXHF3J8VDLUA7XE92 US4592001014 0000051143 4295904307 459200101 49EB20 IBM',
#     'Roe': 45.252147,
#     'OrganisationStatus': 'Listed',
#     'CurrentLiabilities': 37701000000,
#     'PrimaryRICTickerSymbol': 'IBM',
#     'RCSCountryHeadquartersNameML': 'ja 国際機関\\\\米国|zh-Hans 国家分组\\\\美国|zh-Hant 國家分組\\\\美國|es \\\\Estados Unidos|fr \\\\États Unis|ko \\\\미국|ru \\\\США|ja 国際機関\\\\米国|zh-Hans 国家分组\\北大西洋公约组织\\美国|zh-Hant 國家分組\\北大西洋公約組織\\美國|es \\\\Estados Unidos|fr \\\\États Unis|ko \\\\미국|ru \\\\США|es Continentes/regiones\\Continente Americano\\Norteamérica\\Estados Unidos|fr Continents/Régions\\Amérique\\Amérique du Nord\\États Unis|ja 大陸 / 地域\\北米 & 中南米\\北米\\米国|ru Континенты/регионы\\Америка\\Северная Америка\\США|zh-Hans 大陆/地区\\美洲\\北美\\美国|zh-Hant 大陸/地區\\美洲\\北美\\美國|ko \\미주\\북아메리카\\미국|ja 国際機関\\\\米国|zh-Hans 国家分组\\亚太经济合作组织\\美国|zh-Hant 國家分組\\亞太經濟合作組織\\美國|es \\\\Estados Unidos|fr \\\\États Unis|ko \\\\미국|ru \\\\США|ja 国際機関\\\\米国|zh-Hans 国家分组\\经济合作与发展组织\\美国|zh-Hant 國家分組\\經濟合作與發展組織\\美國|es \\\\Estados Unidos|fr \\\\États Unis|ko \\\\미국|ru \\\\США|ja 国際機関\\\\米国|zh-Hans 国家分组\\\\美国|zh-Hant 國家分組\\\\美國|es \\\\Estados Unidos|fr \\\\États Unis|ko \\\\미국|ru \\\\США|ja 国\\米国|zh-Hans 国家/地区\\美国|zh-Hant 國家/地區\\美國|es \\Estados Unidos|fr \\États Unis|ko \\미국|ru \\США|ja 国際機関\\\\米国|zh-Hans 国家分组\\\\美国|zh-Hant 國家分組\\\\美國|es \\\\Estados Unidos|fr \\\\États Unis|ko \\\\미국|ru \\\\США|ja FRUC 地域\\グローバル\\北米\\米国|zh-Hans FRUC 区域\\全球\\北美\\美国|zh-Hant FRUC 區域\\全球\\北美\\美國|es \\\\\\Estados Unidos|fr \\\\\\États Unis|ko \\\\\\미국|ru \\\\\\США|ja 国際機関\\\\米国|zh-Hans 国家分组\\G10 集团\\美国|zh-Hant 國家分組\\G10 集團\\美國|es \\\\Estados Unidos|fr \\\\États Unis|ko \\\\미국|ru \\\\США|ja 国際機関\\北アフリカ (EIU)\\米国|zh-Hans 国家分组\\北美 (EIU)\\美国|zh-Hant 國家分組\\北美 (EIU)\\美國|es \\\\Estados Unidos|fr \\\\États Unis|ko \\\\미국|ru \\\\США',
#     'RCSTRBC2012LeafML': 'ja IT サービス & コンサルティング (その他)|zh-Hans IT 服务及咨询 (NEC)|zh-Hant IT 服務及諮詢 (NEC)',
#     'WarrantsCount': 3069,
#     'ParentOrganisationOrgid': '18228',
#     'DocumentTitle': 'International Business Machines Corp, Public Company',
#     'ShortName': 'IBM',
#     'DEBUGRANKRULES': '200001|300000',
#     'DTSimpleType': 'Public Company',
#     'UnderlyingEquityQuoteIssueCount': 0,
#     'Revenue': 77147000000,
#     'IsShariahCompliant': False,
#     'RCSTRBC2012Leaf': 'IT Services & Consulting (NEC)',
#     'IsPreIPO': False,
#     'PretaxProfitInterim': 1827000000,
#     'ReutersIndustryClassification': 'Data Processing & Reproduction',
#     'OpProfit': 10721000000,
#     'RatingX1XRatingRank': 'FDL/WDX1X98|EJC/A1X1X2|MCP/P-1X1X1|MDL/A2X1X7|MIS/A2X1X7|EJC/A1X1X2|MIS/A2X1X7|FCP/WDX1X98|MDL/A2X1X7|MSU/A2X1X7|FSS/WDX1X98|FSU/AX1X7|MSU/A2X1X7|MCP/P-1X1X1|FMU/WDX1X98|FDT/F1X1X2|MMU/WRX1X98|FSU/WDX1X98|MRS/P-1X1X1|EJU/BBB+X1X8|EJU/BBB+X1X8|FDS/WDX1X98|FIS/WDX1X98|MMU/WRX1X98|FCP/F1X1X2',
#     'SuggestCompletion': [{'input': ['big',
#        'big blue',
#        'company',
#        'corporation',
#        'guo',
#        'guo ji',
#        'guo ji shang',
#        'guo ji shang ye',
#        'guo ji shang ye ji',
#        'guo ji shang ye ji qi',
#        'guo ji shang yong',
#        'guo ji shang yong ji',
#        'guo ji shang yong ji qi',
#        'ibm',
#        'intanashonaru',
#        'intanashonaru bijinesu',
#        'intanashonaru bijinesu mashinzu',
#        'international',
#        'international business',
#        'international business machines',
#        'international business machines corp',
#        'international business machines corporation',
#        'software',
#        'software artistry',
#        'software artistry inc',
#        'unison',
#        'unison software',
#        'unison software inc'],
#       'weight': 6453131},
#      {'input': ['company',
#        'corporation',
#        'ibm',
#        'it',
#        'it services',
#        'it services & consulting',
#        'it services & consulting (nec)'],
#       'weight': 1000000},
#      {'input': ['united', 'united states'], 'weight': 7000000}],
#     'CompositeSearchAll': 'IT Services & Consulting (NEC) ORGANISATION Corporation Listed',
#     'Rofa': 10.032872,
#     'NetProfitUsd': 9431000000,
#     'MortgagesCount': 0,
#     'AddressPostalCode': '10504-1722',
#     'IsMainIssueFiling': True,
#     'PrimaryRICISIN': 'US4592001014',
#     'RCSTRBC2012Genealogy': 'B:278\\B:171\\B:172\\B:290\\B:1790',
#     'Nd': 54031000000,
#     'PrimaryRICRICAcctsCount': 3047,
#     'LoanCount': 0,
#     'FtseScheme': 'Information Technology/Software & Computer Services/Computer Services',
#     'StaffCosts': -453000000,
#     'CPERMIDs': 'C000002474',
#     'IssuerCikNumber': '0000051143',
#     'CashAndEquivalents': 8172000000,
#     'RCSCountryHeadquartersLeaf': 'United States',
#     'CurrentAssets': 38420000000,
#     'PrimaryRICRCSAssetCategoryLeaf': 'Ordinary Share',
#     'RCSCountryOfIncorporation': 'G:6J',
#     'PrimaryRICExchangeCode': 'NYQ',
#     'TotalAssetsToEquity': 7.302241,
#     'SPsRatingX1XSPsRatingRankDomestic': 'SIS/A-1X1X2|SSU/AX1X11|SMU/AX1X11|SPI/AX1X6',
#     'Ratings': '<EntityList xmlns="uri://GenericEntityContainer_2.xsd"><Entity name="Rating"><Property name="Agency" value="Fitch"/><Property name="RatingType" value="Fitch Long-term Issuer Default Rating"/><Property name="RatingTypeCode" value="FDL"/><Property name="CurrentRating" value="WD"/><Property name="CurrentRatingDate" value="2019-07-01"/><Property name="Preliminary" value="n"/><Property name="Solicited" value="n"/><Property name="RatingScope" value="F"/></Entity><Entity name="Rating"><Property name="Agency" value="Egan-Jones Ratings Co."/><Property name="RatingType" value="Egan-Jones Commercial Paper"/><Property name="RatingTypeCode" value="EJC"/><Property name="CurrentRating" value="A1"/><Property name="CurrentRatingDate" value="2018-11-02"/><Property name="Preliminary" value="n"/><Property name="Solicited" value="n"/><Property name="RatingScope" value="D"/></Entity><Entity name="Rating"><Property name="Agency" value="Moody&apos;s"/><Property name="RatingType" value="Moody&apos;s Commercial Paper"/><Property name="RatingTypeCode" value="MCP"/><Property name="CurrentRating" value="P-1"/><Property name="CurrentRatingDate" value="2016-03-30"/><Property name="Preliminary" value="n"/><Property name="Solicited" value="n"/><Property name="RatingScope" value="D"/></Entity><Entity name="Rating"><Property name="Agency" value="Moody&apos;s"/><Property name="RatingType" value="Moody&apos;s Derived Long-term Issuer Rating"/><Property name="RatingTypeCode" value="MDL"/><Property name="CurrentRating" value="A2"/><Property name="CurrentRatingDate" value="2019-07-09"/><Property name="Preliminary" value="n"/><Property name="Solicited" value="n"/><Property name="Outlook" value="Stable"/><Property name="RatingScope" value="F"/></Entity><Entity name="Rating"><Property name="Agency" value="Moody&apos;s"/><Property name="RatingType" value="Moody&apos;s Long-term Issuer Rating"/><Property name="RatingTypeCode" value="MIS"/><Property name="CurrentRating" value="A2"/><Property name="CurrentRatingDate" value="2019-07-09"/><Property name="Preliminary" value="n"/><Property name="Solicited" value="n"/><Property name="RatingScope" value="D"/></Entity><Entity name="Rating"><Property name="Agency" value="Egan-Jones Ratings Co."/><Property name="RatingType" value="Egan-Jones Commercial Paper"/><Property name="RatingTypeCode" value="EJC"/><Property name="CurrentRating" value="A1"/><Property name="CurrentRatingDate" value="2019-01-30"/><Property name="Preliminary" value="n"/><Property name="Solicited" value="n"/><Property name="RatingScope" value="F"/></Entity><Entity name="Rating"><Property name="Agency" value="Moody&apos;s"/><Property name="RatingType" value="Moody&apos;s Long-term Issuer Rating"/><Property name="RatingTypeCode" value="MIS"/><Property name="CurrentRating" value="A2"/><Property name="CurrentRatingDate" value="2019-07-09"/><Property name="Preliminary" value="n"/><Property name="Solicited" value="n"/><Property name="RatingScope" value="F"/></Entity><Entity name="Rating"><Property name="Agency" value="Fitch"/><Property name="RatingType" value="Fitch Commercial Paper"/><Property name="RatingTypeCode" value="FCP"/><Property name="CurrentRating" value="WD"/><Property name="CurrentRatingDate" value="2019-07-01"/><Property name="Preliminary" value="n"/><Property name="Solicited" value="n"/><Property name="RatingScope" value="F"/></Entity><Entity name="Rating"><Property name="Agency" value="Moody&apos;s"/><Property name="RatingType" value="Moody&apos;s Derived Long-term Issuer Rating"/><Property name="RatingTypeCode" value="MDL"/><Property name="CurrentRating" value="A2"/><Property name="CurrentRatingDate" value="2019-07-09"/><Property name="Preliminary" value="n"/><Property name="Solicited" value="n"/><Property name="Outlook" value="Stable"/><Property name="RatingScope" value="D"/></Entity><Entity name="Rating"><Property name="Agency" value="Moody&apos;s"/><Property name="RatingType" value="Moody&apos;s Senior Unsecured"/><Property name="Rat ...
#     'SDCCUSIP': '459200',
#     'Edcoid': 'IBM.N',
#     'LocalScheme': 'Industrial|Information Technology/Information Technology Hardware|Industrials/Computer Hardware',
#     'BusinessIntelligenceExists': True,
#     'QuickRatio': 0.976128,
#     'VEFirmID': '21142',
#     'CommonNameJaHira': 'いんたーなしょなるびじねすましーんずこーぽれーしょん',
#     'RCSTRBC': 'B:173',
#     'PI': '37036',
#     'Rota': 6.844772,
#     'VentureEconomicsID': '99636',
#     'PrimaryRICExchangeName': 'NYSE Consolidated',
#     'IsContributor': False,
#     'RatingRank': 'FDL/98|EJC/2|MCP/1|MDL/7|MIS/7|EJC/2|MIS/7|FCP/98|MDL/7|MSU/7|FSS/98|FSU/7|MSU/7|MCP/1|FMU/98|FDT/2|MMU/98|FSU/98|MRS/1|EJU/8|EJU/8|FDS/98|FIS/98|MMU/98|FCP/2',
#     'OpProfitUsd': 10721000000,
#     'RatingOutlookX1XRatingOutlookRank': 'MDL/StableX1X0|MDL/StableX1X0|MRS/StableX1X0',
#     'MarkItShortName': 'Intl Business Machs Corp',
#     'Rank': 2838774,
#     'SearchAllCategoryv2': 'Companies/Issuers',
#     'MXID': '100085757',
#     'SalesToReceivables': 2.63967,
#     'CountryHeadquartersName': 'United States',
#     'ForecastDividendCashflowRIC': '<a:Rship name="x" xmlns:a="http://www.reuters.com/ns/2007/10/31/webservices/SearchAndNavigation_1/NavCommonResponse_1"><a:Entity><a:Prop name="RIC" value="IBMDIVCF.N"/><a:Req value="145" scheme="IDN"/></a:Entity></a:Rship>',
#     'SearchAllCategoryv3': 'Companies/Issuers',
#     'TaxID': '130871985',
#     'MnaParentAcquirerCount': 0,
#     'TRBCHierarchicalCodeMeaning': 'IT Services & Consulting - NEC',
#     'PretaxProfit': 10166000000,
#     'UnderlyingEquityOptionIssueCount': 0,
#     'DocDateTime': '2020-12-10T14:57:47.000Z',
#     'RCSOrganisationTypeLeafML': 'ja 事業法人|zh-Hans 公司|zh-Hant 公司',
#     'SPsRatingsScope': [{'Agency': 'S&P',
#       'RatingType': 'SIS',
#       'CurrentRatingRank': 2,
#       'CurrentRatingDate': '2017-05-05T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'RatingScope': 'D'},
#      {'Agency': 'S&P',
#       'RatingType': 'SSU',
#       'CurrentRatingRank': 11,
#       'CurrentRatingDate': '2018-10-29T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'RatingScope': 'D'},
#      {'Agency': 'S&P',
#       'RatingType': 'SIS',
#       'CurrentRatingRank': 2,
#       'CurrentRatingDate': '2017-05-05T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'RatingScope': 'F'},
#      {'Agency': 'S&P',
#       'RatingType': 'SSU',
#       'CurrentRatingRank': 11,
#       'CurrentRatingDate': '2018-10-29T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'RatingScope': 'F'},
#      {'Agency': 'S&P',
#       'RatingType': 'SPI',
#       'CurrentRatingRank': 6,
#       'CurrentRatingDate': '2018-10-29T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'OutlookRank': -1,
#       'RatingScope': 'F',
#       'Outlook': 'Negative'},
#      {'Agency': 'S&P',
#       'RatingType': 'SMU',
#       'CurrentRatingRank': 11,
#       'CurrentRatingDate': '2018-10-29T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'RatingScope': 'D'},
#      {'Agency': 'S&P',
#       'RatingType': 'SCP',
#       'CurrentRatingRank': 2,
#       'CurrentRatingDate': '2017-05-05T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'RatingScope': 'F'},
#      {'Agency': 'S&P',
#       'RatingType': 'SPI',
#       'CurrentRatingRank': 6,
#       'CurrentRatingDate': '2018-10-29T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'OutlookRank': -1,
#       'RatingScope': 'D',
#       'Outlook': 'Negative'},
#      {'Agency': 'S&P',
#       'RatingType': 'SMU',
#       'CurrentRatingRank': 0,
#       'CurrentRatingDate': '2011-05-13T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'RatingScope': 'F'}],
#     'TRBCPrimaryCodeMeaning': 'IT Services & Consulting',
#     'OrgMainRepno': '4741N',
#     'AddressStateProvince': 'NEW YORK',
#     'TotalLiabilitiesUsd': 131201000000,
#     'RCSCountryHeadquartersGenealogy': 'M:DQ\\G:AM\\G:6J|M:DQ\\G:AN\\G:6J|M:DH\\G:4\\G:9\\G:6J|M:DQ\\G:AQ\\G:6J|M:DQ\\G:AR\\G:6J|M:DQ\\G:AS\\G:6J|M:A9\\G:6J|M:DQ\\G:B9\\G:6J|M:1M2\\G:3U8\\G:3U9\\G:6J|M:DQ\\G:CX\\G:6J|M:DQ\\G:DE\\G:6J',
#     'RevenueGrowthInterim': -2.595962,
#     'OAOrgType': 'COM',
#     'GicsLeaf': 'IT Consulting & Other Services',
#     'GeneralAliasNameJaHani': 'インターナショナル・ビジネス・マシーンズ',
#     'FDS': 'IBM',
#     'MarketCapitalisationIndices': '<a:Rship name="x" xmlns:a="http://www.reuters.com/ns/2007/10/31/webservices/SearchAndNavigation_1/NavCommonResponse_1"><a:Entity rank="1"><a:Prop name="DisplayName" value="道琼斯工业平均指数" lang="zh-Hans"/><a:Prop name="RIC" value=".DJI"/><a:Req value="9822" scheme="IDN"/><a:Req value="4017" scheme="IDN"/></a:Entity><a:Entity rank="2"><a:Prop name="DisplayName" value="DJ工業株30種平均指数" lang="ja-Hani"/><a:Prop name="RIC" value=".DJI"/><a:Req value="9822" scheme="IDN"/><a:Req value="4017" scheme="IDN"/></a:Entity><a:Entity rank="3"><a:Prop name="DisplayName" value="DOW JONES INDU AVERAGE NDX" lang="en"/><a:Prop name="RIC" value=".DJI"/><a:Req value="9822" scheme="IDN"/><a:Req value="4017" scheme="IDN"/></a:Entity><a:Entity rank="4"><a:Prop name="DisplayName" value="DJ COMP AVERAGE" lang="en"/><a:Prop name="RIC" value=".DJA"/><a:Req value="9822" scheme="IDN"/><a:Req value="4017" scheme="IDN"/></a:Entity><a:Entity rank="5"><a:Prop name="DisplayName" value="道琼斯综合指数" lang="zh-Hans"/><a:Prop name="RIC" value=".DJA"/><a:Req value="9822" scheme="IDN"/><a:Req value="4017" scheme="IDN"/></a:Entity><a:Entity rank="6"><a:Prop name="DisplayName" value="DJ コンポジット平均" lang="ja-Hani"/><a:Prop name="RIC" value=".DJA"/><a:Req value="9822" scheme="IDN"/><a:Req value="4017" scheme="IDN"/></a:Entity><a:Entity rank="7"><a:Prop name="DisplayName" value="S&amp;P Composite 1500 Index" lang="en"/><a:Prop name="RIC" value=".SPSUP"/><a:Req value="5185" scheme="IDN"/><a:Req value="5775" scheme="IDN"/></a:Entity><a:Entity rank="8"><a:Prop name="DisplayName" value="DOW JONES GL TITAN 50 EUR NDX" lang="en"/><a:Prop name="RIC" value=".DJGTE"/><a:Req value="9822" scheme="IDN"/><a:Req value="4017" scheme="IDN"/></a:Entity><a:Entity rank="9"><a:Prop name="DisplayName" value="Refinitiv United States Price Return Index" lang="en"/><a:Prop name="RIC" value=".TRXFLDUSP"/><a:Req value="7642" scheme="IDN"/></a:Entity><a:Entity rank="10"><a:Prop name="DisplayName" value="Refinitiv North America Price Return Index" lang="en"/><a:Prop name="RIC" value=".TRXFLDNAPU"/><a:Req value="7642" scheme="IDN"/></a:Entity><a:Entity rank="11"><a:Prop name="DisplayName" value="Refinitiv NAFTA Price Return Index" lang="en"/><a:Prop name="RIC" value=".TRXFLDNFPU"/><a:Req value="7642" scheme="IDN"/></a:Entity><a:Entity rank="12"><a:Prop name="DisplayName" value="Refinitiv G7 Price Return Index" lang="en"/><a:Prop name="RIC" value=".TRXFLDG7PU"/><a:Req value="3112" scheme="IDN"/></a:Entity><a:Entity rank="13"><a:Prop name="DisplayName" value="Refinitiv Global Price Return Index" lang="en"/><a:Prop name="RIC" value=".TRXFLDGLPU"/><a:Req value="3112" scheme="IDN"/></a:Entity></a:Rship>',
#     'ShareholdersEquity': 20841000000,
#     'PretaxProfitMargin': 0.131774,
#     'LegalNameJaKana': 'インターナショナルビジネスマシーンズコーポレーション',
#     'RCSOrganisationSubTypeLeaf': 'Company',
#     'IssuersUltimateParentHasCDS': True,
#     'IssuerHasCds': True,
#     'ListingStatus': 'LIS',
#     'ShareholdersEquityUsd': 20841000000,
#     'FuturesCount': 28,
#     'DocumentTitleJaHani': 'インターナショナル･ビジネス･マシーンズ･コーポレーション, Public Company',
#     'RCSOrganisationSubTypeNameML': 'ja OA 組織サブタイプ\\法人|zh-Hans OA 组织子类型\\公司',
#     'SPsRatingType': 'Issuer/S&P/SIS|Issuer/S&P/SSU|Issuer/S&P/SIS|Issuer/S&P/SSU|Issuer/S&P/SPI|Issuer/S&P/SMU|Issuer/S&P/SCP|Issuer/S&P/SPI|Issuer/S&P/SMU',
#     'SalesToInventory': 46.741593,
#     'EquityIndices': '.DJA~DLM~en:DJ COMP AVERAGE|DLM|.DJA~DLM~ja-Hani:DJ コンポジット平均|DLM|.DJA~DLM~zh-Hans:道琼斯综合指数|DLM|.DJGTE~DLM~en:DOW JONES GL TITAN 50 EUR NDX|DLM|.DJGT~DLM~en:Dow Jones Global Titans Index|DLM|.DJI~DLM~en:DOW JONES INDU AVERAGE NDX|DLM|.DJI~DLM~ja-Hani:DJ工業株30種平均指数|DLM|.DJI~DLM~zh-Hans:道琼斯工业平均指数|DLM|.DJUSTC~DLM~en:DOW JONES TECHNOLOGY NDX|DLM|.IVX~DLM~en:S&P 500 Value Index|DLM|.NYA~DLM~en:NYSE COMPOSITE|DLM|.NYA~DLM~ja-Hani:NYSE 総合指数|DLM|.OEXA~DLM~en:S&P 100 INDEX|DLM|.OEXA~DLM~ja-Hani:S&P 100種 指数|DLM|.OEXA~DLM~zh-Hans:标普100指数|DLM|.SPCOMIS~DLM~en:S&P Composite 1500 Software&Serv(IG)|DLM|.SPCOMITCS~DLM~en:S&P 1500 IT Services (Ind)|DLM|.SPCOMTKCS~DLM~en:S&P 1500 ITConsulting&Other Serv(SI)|DLM|.SPCOMT~DLM~en:S&P 1500 Info Technology (Sector)|DLM|.SPLGMID~DLM~en:S&P 900 INDEX|DLM|.SPLRCIS~DLM~en:S&P 500 Software & Services (IG)|DLM|.SPLRCITCS~DLM~en:S&P 500 IT Services (Industry)|DLM|.SPLRCTKCS~DLM~en:S&P 500 IT Consulting&Other Serv(SI)|DLM|.SPLRCT~DLM~en:S&P 500 Information Tech(Sector)|DLM|.SPLRCT~DLM~ja-Hani:S&P 500種 情報技術セクター指数|DLM|.SPLRCT~DLM~zh-Hans:标普信息技术指数|DLM|.SPSUP~DLM~en:S&P Composite 1500 Index|DLM|.SPX~DLM~en:S&P 500 INDEX|DLM|.SPX~DLM~ja-Hani:S&P 500 指数|DLM|.SPX~DLM~zh-Hans:标普500指数|DLM|.SX150P~DLM~en:STXGL150 INDEX CHAIN|DLM|.TRAFWLP1~DLM~en:Refinitiv StarMine Affinity World Leaders Price Return Index (USD)|DLM|.TRENVUS1~DLM~en:Refinitiv/S-Network US Large Cap Environmental Best Practices Index (USD)|DLM|.TRENVUSE1~DLM~en:Refinitiv/S-Network US Large Cap Environmental Best Practices Index (EUR)|DLM|.TRESGQ1~DLM~en:RF IX GL ESG Equal Weighted PR|DLM|.TRESGUS1~DLM~en:Refinitiv/S-Network US Large Cap ESG Best Practices Index (USD)|DLM|.TRESGUSE1~DLM~en:Refinitiv/S-Network US Large Cap ESG Best Practices Index (EUR)|DLM|.TRESGZQ1~DLM~en:RF IX GL ESG HDLV Equal Weighted PR|DLM|.TRGRPSE1~DLM~en:Refinitiv GL Resource Protection Select|DLM|.TRSCUS1~DLM~en:Refinitiv/S-Network US Large Cap Social Best Practices Index (USD)|DLM|.TRSCUSE1~DLM~en:Refinitiv/S-Network US Large Cap Social Best Practices Index (EUR)|DLM|.TRX500USP~DLM~en:Refinitiv United States 500 Price Return Index|DLM|.TRXFLDAAPU~DLM~en:Refinitiv Americas Price Return Index|DLM|.TRXFLDAATL~DLM~en:RF AMERICAS TR LCY IDX|DLM|.TRXFLDG7PUSVIT~DLM~en:Refinitiv G7 IT Services & Consulting Price Return Index|DLM|.TRXFLDG7PUT21~DLM~en:Refinitiv G7 Software & IT Services-572010 Price Return Index|DLM|.TRXFLDG7PUT2~DLM~en:Refinitiv G7 Software & IT Services-5720 Price Return Index|DLM|.TRXFLDG7PUTEC~DLM~en:Refinitiv G7 Technology Price Return Index|DLM|.TRXFLDG7PU~DLM~en:Refinitiv G7 Price Return Index|DLM|.TRXFLDGAPUUSD~DLM~en:Refinitiv Global AUD Price Return Index (USD)|DLM|.TRXFLDGAPU~DLM~en:Refinitiv Global AUD Price Return Index (AUD)|DLM|.TRXFLDGATUUSD~DLM~en:Refinitiv Global AUD Total Return Index (USD)|DLM|.TRXFLDGDPUSVIT~DLM~en:Refinitiv Global Developed IT Services & Consulting Price Return Index|DLM|.TRXFLDGDPUT21~DLM~en:Refinitiv Global Developed Software & IT Services-572010 Price Return Index|DLM|.TRXFLDGDPUT2~DLM~en:Refinitiv Global Developed Software & IT Services-5720 Price Return Index|DLM|.TRXFLDGDPUTEC~DLM~en:Refinitiv Global Developed Technology Price Return Index|DLM|.TRXFLDGDPU~DLM~en:Refinitiv Global Developed Price Return Index|DLM|.TRXFLDGFPU~DLM~en:Refinitiv Global Ex Frontier Large and Mid Cap Price Return Index (USD)|DLM|.TRXFLDGLPUSVIT~DLM~en:Refinitiv Global IT Services & Consulting Price Return Index|DLM|.TRXFLDGLPUT21~DLM~en:Refinitiv Global Software & IT Services-572010 Price Return Index|DLM|.TRXFLDGLPUT2~DLM~en:Refinitiv Global Software & IT Services-5720 Price Return Index|DLM|.TRXFLDGLPUTEC~DLM~en:Refinitiv Global Technology Price Return Index|DLM|.TRXFLDGLPU~DLM~en:Refinitiv Global Price Return Index|DLM|.TRXFLDGLTL~DLM~en:RF GLOBAL TR LCY IDX|DLM|.TRXFLDGSPUUSD~DLM~en:Refinitiv Global Developed Ex Australia Price Return Index (USD)|DLM|.TRXFLDGSPU~DLM~en:Refinitiv Global Developed Ex Australia Price Return Index  ...
#     'RCSOrganisationTypeName': 'Corporation',
#     'MnaAcquirerCount': 0,
#     'MnaSellerCount': 0,
#     'ParentOrganisationName': 'International Business Machines Corp',
#     'ImpliedVolatilityRIC': '<a:Rship name="x" xmlns:a="http://www.reuters.com/ns/2007/10/31/webservices/SearchAndNavigation_1/NavCommonResponse_1"><a:Entity><a:Prop name="RIC" value="IBMATMIV.U"/><a:Req value="6410" scheme="IDN"/><a:Req value="4018" scheme="IDN"/></a:Entity></a:Rship>',
#     'RCSFilingCountryLeafML': 'ja 米国|zh-Hans 美国|zh-Hant 美國|es Estados Unidos|fr États Unis|ko 미국|ru США',
#     'OptionsCount': 1058,
#     'DocumentTitleJaKana': 'インターナショナルビジネスマシーンズコーポレーション, Public Company',
#     'RatingNameX1XRatingType': "Issuer|Issuer/FitchX1XFTC|Issuer/FitchX1XFTC/Fitch Long-term Issuer Default RatingX1XFDL|Issuer/Egan-Jones Ratings Co.X1XEGJ|Issuer/Egan-Jones Ratings Co.X1XEGJ/Egan-Jones Commercial PaperX1XEJC|Issuer/Moody'sX1XMDY|Issuer/Moody'sX1XMDY/Moody's Commercial PaperX1XMCP|Issuer/Moody'sX1XMDY/Moody's Derived Long-term Issuer RatingX1XMDL|Issuer/Moody'sX1XMDY/Moody's Long-term Issuer RatingX1XMIS|Issuer/FitchX1XFTC/Fitch Commercial PaperX1XFCP|Issuer/Moody'sX1XMDY/Moody's Senior UnsecuredX1XMSU|Issuer/FitchX1XFTC/Fitch Short-term Issuer RatingX1XFSS|Issuer/FitchX1XFTC/Fitch Senior UnsecuredX1XFSU|Issuer/FitchX1XFTC/Fitch Long-term Senior Unsecured MTN RatingX1XFMU|Issuer/FitchX1XFTC/Fitch Short-term Debt RatingX1XFDT|Issuer/Moody'sX1XMDY/Moody's Long-term Senior Unsecured MTN RatingX1XMMU|Issuer/Moody'sX1XMDY/Moody's Most Recent Short-term RatingX1XMRS|Issuer/Egan-Jones Ratings Co.X1XEGJ/Egan-Jones Senior UnsecuredX1XEJU|Issuer/FitchX1XFTC/Fitch Short-term Issuer Default RatingX1XFDS|Issuer/FitchX1XFTC/Fitch Long-term Issuer RatingX1XFIS",
#     'SponsorBondsExist': False,
#     'ICBSchemeName': 'Technology/Technology/Software & Computer Services/Computer Services',
#     'RCSOrganisationSubTypeGenealogy': 'M:1NJ\\OAOST:COR',
#     'REC': 'IBM',
#     'TRBC2012PrimaryCodeMeaning': 'Technology/Software & IT Services/Software & IT Services/IT Services & Consulting/IT Services & Consulting - NEC',
#     'RCSFilingCountryGenealogy': 'M:DQ\\G:AM\\G:6J|M:DQ\\G:AN\\G:6J|M:DH\\G:4\\G:9\\G:6J|M:DQ\\G:AQ\\G:6J|M:DQ\\G:AR\\G:6J|M:DQ\\G:AS\\G:6J|M:A9\\G:6J|M:DQ\\G:B9\\G:6J|M:1M2\\G:3U8\\G:3U9\\G:6J|M:DQ\\G:CX\\G:6J|M:DQ\\G:DE\\G:6J',
#     'SPsRatingX1XSPsRatingRank': 'SIS/A-1X1X2|SSU/AX1X11|SIS/A-1X1X2|SSU/AX1X11|SPI/AX1X6|SMU/AX1X11|SCP/A-1X1X2|SPI/AX1X6|SMU/NRX1X0',
#     'CompositeDescriptiveNameZh': '国际商业机器公司|国际商用机器',
#     'OrganisationType': 'CO',
#     'ICBScheme': '9533',
#     'SalesToAssets': 0.559913,
#     'UltimateParentOrganizationID': '4295904307',
#     'RCSCountryOfIncorporationLeaf': 'United States',
#     'EquitiesCount': 98,
#     'RCSOrganisationSubTypeLeafML': 'ja 法人|zh-Hans 公司',
#     'RCSPartyCountryLeaf': 'United States',
#     'CompositeDescriptiveName': 'Big Blue|Guo Ji Shang Ye Ji Qi Gong Si|Guo Ji Shang Yong Ji Qi|IBM|Intanashonaru Bijinesu Mashinzu|International Business Machines|Software Artistry Inc|Unison Software Inc INTERNATIONAL BUSINESS MACHINES CORPORATION International Business Machines Corp IBM',
#     'RevenueInterim': 17560000000,
#     'ActiveEstimatesExist': True,
#     'LegalName': 'INTERNATIONAL BUSINESS MACHINES CORPORATION',
#     'EquityDividends': -5707000000,
#     'BondsCount': 46,
#     'RCSOrganisationTypeLeaf': 'Corporation',
#     'CountryHeadquarters': 'USA',
#     'LEI': 'VGRQXHF3J8VDLUA7XE92',
#     'RCSOrganisationSubTypeName': 'OA Organization Subtype\\Company',
#     'CompositeDescriptiveNameJa': 'インターナショナル･ビジネス･マシーンズ･コーポレーション インターナショナルビジネスマシーンズコーポレーション いんたーなしょなるびじねすましーんずこーぽれーしょん インターナショナル・ビジネス・マシーンズ',
#     'MoodysIssuerRating': 'A2',
#     'Ebitda': 16780000000,
#     'ERRORS': ['VPIP CompanyOfficers',
#      'VPIP RCSCountryOfIncorporationGenealogy',
#      'VPIP GeneralAliasNameZhHans',
#      'VPIP CalaisAlias',
#      'VPIP GeneralAliasName',
#      'VPIP RCSFilingCountryName',
#      'VPIP RCSCountryHeadquartersName',
#      'VPIP LocalScheme',
#      'VPIP RCSCountryHeadquartersGenealogy',
#      'VPIP EquityIndices',
#      'VPIP RCSFilingCountryGenealogy']},
#    'copy_targets': {'symbol': ['18228',
#      'VGRQXHF3J8VDLUA7XE92 US4592001014 0000051143 4295904307 459200101 49EB20 IBM'],
#     'code': ['VGRQXHF3J8VDLUA7XE92 US4592001014 0000051143 4295904307 459200101 49EB20 IBM'],
#     'namezh': ['国际商业机器公司|国际商用机器'],
#     'SearchAllJa': ['事業法人',
#      'インタナショナル コーポレイション インタナショナル コーポレイション',
#      'インターナショナル･ビジネス･マシーンズ･コーポレーション インターナショナルビジネスマシーンズコーポレーション いんたーなしょなるびじねすましーんずこーぽれーしょん インターナショナル・ビジネス・マシーンズ'],
#     'RCSOriginalAccountsCurrencyGenealogy': ['C:6'],
#     'RCSOriginalAccountsCurrencyNameML': ['ja 米ドル|zh-Hans 美元|zh-Hant 美元'],
#     'name': ['internatnl INTL intrnl internatnl INTL intrnl',
#      'Big Blue|Guo Ji Shang Ye Ji Qi Gong Si|Guo Ji Shang Yong Ji Qi|IBM|Intanashonaru Bijinesu Mashinzu|International Business Machines|Software Artistry Inc|Unison Software Inc INTERNATIONAL BUSINESS MACHINES CORPORATION International Business Machines Corp IBM'],
#     'SearchAllSymbol': ['18228',
#      'VGRQXHF3J8VDLUA7XE92 US4592001014 0000051143 4295904307 459200101 49EB20 IBM'],
#     'SearchAllZh': ['公司', '国际商业机器公司|国际商用机器'],
#     'RCSOriginalAccountsCurrencyName': ['US Dollar'],
#     'nameja': ['インタナショナル コーポレイション インタナショナル コーポレイション',
#      'インターナショナル･ビジネス･マシーンズ･コーポレーション インターナショナルビジネスマシーンズコーポレーション いんたーなしょなるびじねすましーんずこーぽれーしょん インターナショナル・ビジネス・マシーンズ'],
#     'SearchAllText': ['internatnl INTL intrnl internatnl INTL intrnl',
#      'IT Services & Consulting (NEC) ORGANISATION Corporation Listed',
#      'Big Blue|Guo Ji Shang Ye Ji Qi Gong Si|Guo Ji Shang Yong Ji Qi|IBM|Intanashonaru Bijinesu Mashinzu|International Business Machines|Software Artistry Inc|Unison Software Inc INTERNATIONAL BUSINESS MACHINES CORPORATION International Business Machines Corp IBM']}}]}

# %% [markdown]
# #### Understanding values using Navigators
# Using the output from a debugging session, there are a number of common properties that are very useful when filtering your search.  For example, you may want to filter your results based on a specific category of data.  Using navigators will help us understand these categories.
#
# Looking at our debug output above, one useful property: **SearchAllCategoryv3** will helps us understand all available categories of documents the query term 'IBM' was found.  To list these categories, use the following:

# %%
response=rdp.Search.search(
    query = "IBM",
    top = 0,
    navigators = "SearchAllCategoryv3"
)
response.data.raw["Navigators"]["SearchAllCategoryv3"]["Buckets"]
# Out:
# [{'Label': 'Other Quote', 'Count': 25218},
#  {'Label': 'Warrants', 'Count': 6789},
#  {'Label': 'Bond Pricing', 'Count': 2025},
#  {'Label': 'Bonds', 'Count': 1414},
#  {'Label': 'Commercial Papers', 'Count': 1282},
#  {'Label': 'Options', 'Count': 1062},
#  {'Label': 'Companies/Issuers', 'Count': 773},
#  {'Label': 'Futures', 'Count': 749},
#  {'Label': 'Mergers & Acquisitions', 'Count': 712},
#  {'Label': 'Equities', 'Count': 493},
#  {'Label': 'Credit Default Swaps', 'Count': 463},
#  {'Label': 'Analyst', 'Count': 237},
#  {'Label': 'Officers', 'Count': 140},
#  {'Label': 'FX & Money', 'Count': 66},
#  {'Label': 'Fixed Income Curves', 'Count': 48},
#  {'Label': 'Other Instrument', 'Count': 23},
#  {'Label': 'Mortgage Backed Securities', 'Count': 12},
#  {'Label': 'Funds', 'Count': 10},
#  {'Label': 'People', 'Count': 7},
#  {'Label': 'CMO & ABS', 'Count': 5},
#  {'Label': 'Loans', 'Count': 5},
#  {'Label': 'Buy Side Contact', 'Count': 4},
#  {'Label': 'Fund Manager', 'Count': 4},
#  {'Label': 'ABS & CMO', 'Count': 2},
#  {'Label': 'Commodities Physical Assets', 'Count': 2},
#  {'Label': 'Commodities', 'Count': 1},
#  {'Label': 'Indices', 'Count': 1}]

# %% [markdown]
# Using the above listing, we can narrow our result set based on these categories using a Filter.

# %% [markdown]
# #### Special Properties
# The Search service includes a number of special properties that enhance the ability to find meaningful results. In addition to the special property *_debugall* used within the **select** parameter as outlined above, the following properties are available:

# %%
# The 'code' specification will search across all codes, such as RICs, tickers, SEDOLs etc.  
# Primarily used within a filter but can be used as a selectable property.
rdp.search(
    filter = "code eq 'IBM'"
)
# Out:
#           RIC        PI BusinessEntity  \
# 0        <NA>     37036   ORGANISATION
# 1         IBM   1097326   QUOTExEQUITY
# 2  IBMEUR.xbo  79345498   QUOTExEQUITY
# 3      IBM.BA   1006058   QUOTExEQUITY
# 4       IBM.N   1090370   QUOTExEQUITY
# 5      IBM.TH    765744   QUOTExEQUITY
# 6       IBM.Z  53703996   QUOTExEQUITY
# 7      IBMI.L   1283576   QUOTExEQUITY
# 8       IBM.P    753753   QUOTExEQUITY
# 9      IBM.DG  73533774   QUOTExEQUITY
#
#                                                                                  DocumentTitle  \
# 0                                         International Business Machines Corp, Public Company
# 1                      International Business Machines Corp, Ordinary Share, NYSE Consolidated
# 2   International Business Machines Corp, Ordinary Share, MiFID Composite Cross Market Service
# 3  International Business Machines Corp, Depository Receipt, Bolsa de Comercio de Buenos Aires
# 4                International Business Machines Corp, Ordinary Share, New York Stock Exchange
# 5                     International Business Machines Corp, Ordinary Share, NASDAQ INTERMARKET
# 6                      International Business Machines Corp, Ordinary Share, Cboe BZX Exchange
# 7                  International Business Machines Corp, Ordinary Share, London Stock Exchange
# 8                              International Business Machines Corp, Ordinary Share, NYSE Arca
# 9                     International Business Machines Corp, Ordinary Share, Cboe EDGX Exchange
#
#         PermID
# 0         <NA>
# 1  55839165994
# 2  21475739068
# 3  55838283585
# 4  55838323096
# 5  55835333953
# 6  55845629228
# 7  55836050580
# 8  55837129318
# 9  21475059739

# %%
# The 'name' specification will search across all names, such as common name, legal name, issuer name, etc. 
# Primarily used within a filter but can be used as a selectable property.
rdp.search(
    filter = "name eq 'IBM'",
)
# Out:
#         RIC          PI BusinessEntity  \
# 0      <NA>       37036   ORGANISATION
# 1       IBM     1097326   QUOTExEQUITY
# 2      <NA>       99244   ORGANISATION
# 3      <NA>  4297694029           ORGS
# 4      <NA>    18062670   ORGANISATION
# 5      <NA>    27968389   ORGANISATION
# 6   0#IBMF:    48924732   QUOTExEQUITY
# 7  0#IBMDF:   259118763   QUOTExEQUITY
# 8    IBMFc1    49450681   QUOTExEQUITY
# 9    IBMFc2    50092347   QUOTExEQUITY
#
#                                                                                     DocumentTitle  \
# 0                                            International Business Machines Corp, Public Company
# 1                         International Business Machines Corp, Ordinary Share, NYSE Consolidated
# 2                                                                 IBM Credit LLC, Private Company
# 3                                                      IBM Retirement Fund Trust, Private Company
# 4               Tiers Corporate Bond Backed Certificates Trust Series Ibm 1997 4, Private Company
# 5                      SG Stuttgart Vaihingen BM-Campus 1 UG haftungsbeschraenkt, Private Company
# 6  Eurex International Business Machines Equity Future Chain Contract , Equity Future, USD, Eurex
# 7  Euronext Amsterdam IBM Dividend Future Chain Contracts, Equity Future, USD, Euronext Amsterdam
# 8   Eurex International Business Machines Equity Future Continuation 1, Equity Future, USD, Eurex
# 9   Eurex International Business Machines Equity Future Continuation 2, Equity Future, USD, Eurex
#
#         PermID
# 0         <NA>
# 1  55839165994
# 2         <NA>
# 3         <NA>
# 4         <NA>
# 5         <NA>
# 6  21481052421
# 7  21612423771
# 8  21481052892
# 9  21481053949

# %%
# The special character underscore (_) is a convenient token that can be used to select the default Properties.  
# This will allow users to quickly select the default values plus any other properties when testing out your search.
rdp.search(
    query = "IBM",
    top = 1000,
    select = "_, SearchAllCategoryv3"
)
# Out:
#                  RIC SearchAllCategoryv3          PI BusinessEntity  \
# 0               <NA>   Companies/Issuers       37036   ORGANISATION
# 1                IBM            Equities     1097326   QUOTExEQUITY
# 2               <NA>   Companies/Issuers       99244   ORGANISATION
# 3               <NA>   Companies/Issuers  4297694029           ORGS
# 4               <NA>   Companies/Issuers    18062670   ORGANISATION
# ..               ...                 ...         ...            ...
# 995  IBMX112013800.U             Options   478740173   QUOTExEQUITY
# 996  IBMA222111100.U             Options   478740300   QUOTExEQUITY
# 997  IBMA222112400.U             Options   478740365   QUOTExEQUITY
# 998  IBMA222112000.U             Options   478740487   QUOTExEQUITY
# 999  IBMM222111100.U             Options   478740505   QUOTExEQUITY
#
#                                                                                                                  DocumentTitle  \
# 0                                                                         International Business Machines Corp, Public Company
# 1                                                      International Business Machines Corp, Ordinary Share, NYSE Consolidated
# 2                                                                                              IBM Credit LLC, Private Company
# 3                                                                                   IBM Retirement Fund Trust, Private Company
# 4                                            Tiers Corporate Bond Backed Certificates Trust Series Ibm 1997 4, Private Company
# ..                                                                                                                         ...
# 995    OPRA International Business Machines Equity Option 138 Put Dec 2020 , Equity Cash Option, Put 138 USD 11-Dec-2020, OPRA
# 996  OPRA International Business Machines Equity Option 111 Call Jan 2021 , Equity Cash Option, Call 111 USD 22-Jan-2021, OPRA
# 997  OPRA International Business Machines Equity Option 124 Call Jan 2021 , Equity Cash Option, Call 124 USD 22-Jan-2021, OPRA
# 998  OPRA International Business Machines Equity Option 120 Call Jan 2021 , Equity Cash Option, Call 120 USD 22-Jan-2021, OPRA
# 999    OPRA International Business Machines Equity Option 111 Put Jan 2021 , Equity Cash Option, Put 111 USD 22-Jan-2021, OPRA
#
#           PermID
# 0           <NA>
# 1    55839165994
# 2           <NA>
# 3           <NA>
# 4           <NA>
# ..           ...
# 995  21784725294
# 996  21784725420
# 997  21784725484
# 998  21784725597
# 999  21784725615
#
# [1000 rows x 6 columns]

# %% [markdown]
# #### Common Properties
# As you become more familiar with search, you will soon recognize there will be a number of very useful properties that will act as your "go-tos" when filtering or selecting fields.

# %%
# DocumentTitle
# As you've seen in some of the above output, this property is on by default when you want to display your search results.  
# The DocumentTitle property is a quick way to describe the content retrieved for each matching document.  
# It is made up of the following child properties: 
#    'DTSubjectName', 'DTSimpleType', 'DTSource', and 'DTCharacteristics'.
rdp.search(
    query = "IBM",
    top = 100,
    select = "DocumentTitle, DTSubjectName, DTSimpleType, DTSource, DTCharacteristics"
)
# Out:
#           DTSimpleType         DTCharacteristics           DTSource  \
# 0       Public Company                      <NA>               <NA>
# 1       Ordinary Share                      <NA>  NYSE Consolidated
# 2      Private Company                      <NA>               <NA>
# 3      Private Company                      <NA>               <NA>
# 4      Private Company                      <NA>               <NA>
# ..                 ...                       ...                ...
# 95  Equity Cash Option   Put 123 USD 18-Dec-2020               OPRA
# 96  Equity Cash Option  Call 119 USD 18-Dec-2020               OPRA
# 97  Equity Cash Option  Call 114 USD 18-Dec-2020               OPRA
# 98  Equity Cash Option  Call 123 USD 18-Dec-2020               OPRA
# 99  Equity Cash Option   Put 121 USD 18-Dec-2020               OPRA
#
#                                                                                                                 DocumentTitle  \
# 0                                                                        International Business Machines Corp, Public Company
# 1                                                     International Business Machines Corp, Ordinary Share, NYSE Consolidated
# 2                                                                                             IBM Credit LLC, Private Company
# 3                                                                                  IBM Retirement Fund Trust, Private Company
# 4                                           Tiers Corporate Bond Backed Certificates Trust Series Ibm 1997 4, Private Company
# ..                                                                                                                        ...
# 95    OPRA International Business Machines Equity Option 123 Put Dec 2020 , Equity Cash Option, Put 123 USD 18-Dec-2020, OPRA
# 96  OPRA International Business Machines Equity Option 119 Call Dec 2020 , Equity Cash Option, Call 119 USD 18-Dec-2020, OPRA
# 97  OPRA International Business Machines Equity Option 114 Call Dec 2020 , Equity Cash Option, Call 114 USD 18-Dec-2020, OPRA
# 98  OPRA International Business Machines Equity Option 123 Call Dec 2020 , Equity Cash Option, Call 123 USD 18-Dec-2020, OPRA
# 99    OPRA International Business Machines Equity Option 121 Put Dec 2020 , Equity Cash Option, Put 121 USD 18-Dec-2020, OPRA
#
#                                                            DTSubjectName
# 0                                   International Business Machines Corp
# 1                                   International Business Machines Corp
# 2                                                         IBM Credit LLC
# 3                                              IBM Retirement Fund Trust
# 4       Tiers Corporate Bond Backed Certificates Trust Series Ibm 1997 4
# ..                                                                   ...
# 95   OPRA International Business Machines Equity Option 123 Put Dec 2020
# 96  OPRA International Business Machines Equity Option 119 Call Dec 2020
# 97  OPRA International Business Machines Equity Option 114 Call Dec 2020
# 98  OPRA International Business Machines Equity Option 123 Call Dec 2020
# 99   OPRA International Business Machines Equity Option 121 Put Dec 2020
#
# [100 rows x 5 columns]

# %%
# SearchAllCategoryv3
# When trying to narrow down your search to specific categories, this property can be extremely useful.  
# When you apply a Navigator on this property, it will return a list of ~40 categories, depending on the view. 
# Categories include asset-related instruments such as:
#     'Equities', 'Futures' , 'Options', 'Bonds', 'Commodities' 
#     but can also include things like: 'People', 'Analyst', 'Officers'.
rdp.search(
    query = "IBM",
    filter = "SearchAllCategoryv3 eq 'People'",
)
# Out:
#             PI       PermID BusinessEntity                 DocumentTitle
# 0  34414661717  34414661717         PERSON       John Denham - IsUnknown
# 1  34414669683  34414669683         PERSON  Charlie Maxfield - IsUnknown
# 2  34414721056  34414721056         PERSON   Claudia Barclay - IsUnknown
# 3  34414738667  34414738667         PERSON     Robert Ploder - IsUnknown
# 4  34414743082  34414743082         PERSON       Tom Cadigan - IsUnknown
# 5  34414808510  34414808510         PERSON  R. L. Jay Vivian - IsUnknown
# 6  34415092341  34415092341         PERSON  William E. Baker - IsUnknown

# %%
# CodeResolutionBase
# Represents the most significant codes defined within the document.  For example, when searching for a symbol such 
# as ISIN, SEDOL, RIC, etc, filtering against this property will significantly reduce the matches and only bring 
# back the most relevant results.
rdp.search(
    filter = "CodeResolutionBase eq 'US046353AQ14'",
    select = "DocumentTitle, ISIN, SEDOL, RIC"
)
# Out:
#      SEDOL         RIC          ISIN  \
# 0  BF4SNM7  046353AQ1=  US046353AQ14
#
#                                                                             DocumentTitle
# 0  AstraZeneca PLC, Plain Vanilla Fixed Coupon Bond, TRACE Eligible AZN 2.375 12-Jun-2022

# %%
# Conversely, if we were to choose the more generic term 'code', would result in a wider range of matches.
rdp.search(
    filter = "code eq 'US046353AQ14'",
    select = "DocumentTitle, ISIN, SEDOL, RIC"
)
# Out:
#      SEDOL                RIC          ISIN  \
# 0  BF4SNM7         046353AQ1=  US046353AQ14
# 1  BF4SNM7       046353AQ1=2M          <NA>
# 2  BF4SNM7  US046353AQ14=CSTW          <NA>
# 3  BF4SNM7  US046353AQ14=MKCP          <NA>
# 4  BF4SNM7  US046353AQ14=TDTW          <NA>
# 5  BF4SNM7    US046353AQ14=TE          <NA>
# 6  BF4SNM7     046353AQ1=TWEB          <NA>
# 7  BF4SNM7  US046353AQ14=GFGL          <NA>
# 8  BF4SNM7  US046353AQ14=MKAX          <NA>
# 9  BF4SNM7  US046353AQ14=TEMK          <NA>
#
#                                                                                      DocumentTitle
# 0           AstraZeneca PLC, Plain Vanilla Fixed Coupon Bond, TRACE Eligible AZN 2.375 12-Jun-2022
# 1                AstraZeneca PLC, Bond Quote, TRACE Eligible AZN 2.375 12-Jun-2022, MARKETAXESS L2
# 2  AstraZeneca PLC, Bond Quote, TRACE Eligible AZN 2.375 12-Jun-2022, CREDIT SUISSE TRADEWEB PRICE
# 3    AstraZeneca PLC, Bond Quote, TRACE Eligible AZN 2.375 12-Jun-2022, MARKETAXESS COMPOSITE PLUS
# 4            AstraZeneca PLC, Bond Quote, TRACE Eligible AZN 2.375 12-Jun-2022, TDS TRADEWEB PRICE
# 5                      AstraZeneca PLC, Bond Quote, TRACE Eligible AZN 2.375 12-Jun-2022, TRADEWEB
# 6                      AstraZeneca PLC, Bond Quote, TRACE Eligible AZN 2.375 12-Jun-2022, TRADEWEB
# 7                     AstraZeneca PLC, Bond Quote, TRACE Eligible AZN 2.375 12-Jun-2022, GFI GROUP
# 8          AstraZeneca PLC, Bond Quote, TRACE Eligible AZN 2.375 12-Jun-2022, MARKETAXESS AXESSALL
# 9               AstraZeneca PLC, Bond Quote, TRACE Eligible AZN 2.375 12-Jun-2022, TWEB EUCR MARKS

# %% [markdown]
# #### Common Properties - RCS (Reuters Classification Scheme)
# Throughout many documents, you will notice a number of RCS fields that are popular when selecting and filtering.
#
# *Note* - I'll use navigators to demonstrate the values of these common properties.

# %%
# RCSAssetCategoryLeaf
# Specific to assets, this property will categorize the results into a readable identifier such as: 'Bond', 
# 'Commodity Future', 'Commercial Paper', etc.  Where the property SearchAllCategoryv3 provides general categories, 
# this property will be more specific to assets.  Pull out the top 10.
response = rdp.Search.search(
    top = 0,
    navigators = "RCSAssetCategoryLeaf(buckets:20)"
)
response.data.raw["Navigators"]["RCSAssetCategoryLeaf"]["Buckets"]
# Out:
# [{'Label': 'Barrier Warrant', 'Count': 15700989},
#  {'Label': 'Bond', 'Count': 13616546},
#  {'Label': 'Commodity Future', 'Count': 4530042},
#  {'Label': 'Traditional Warrant', 'Count': 3921203},
#  {'Label': 'Equity Cash Option', 'Count': 3156592},
#  {'Label': 'Commodity Future Option', 'Count': 3073531},
#  {'Label': 'Commodity Spread', 'Count': 2669455},
#  {'Label': 'Equity Future', 'Count': 2665279},
#  {'Label': 'Certificate of Deposit', 'Count': 2629641},
#  {'Label': 'Mortgage-Backed Security', 'Count': 2609478},
#  {'Label': 'Interest Rate Future Spread', 'Count': 2576729},
#  {'Label': 'Commercial Paper', 'Count': 1992080},
#  {'Label': 'Commodity Spot', 'Count': 1793514},
#  {'Label': 'Ordinary Share', 'Count': 1614722},
#  {'Label': 'Buffered Risk / Bonus Certificate', 'Count': 1552475},
#  {'Label': 'Commodity Forward', 'Count': 1506493},
#  {'Label': 'Commodity Cash Option', 'Count': 1278197},
#  {'Label': 'Open-End Fund', 'Count': 1177609},
#  {'Label': 'Warrant', 'Count': 1103059},
#  {'Label': 'Investment Certificate', 'Count': 920563}]

# %%
# RCSCountryLeaf
# RCSIssuerCountryLeaf
# RCSExchangeCountryLeaf
# Specific to some assets, will allow you to narrow your search to focus on a specific country.  Pull out the top 20.
response = rdp.Search.search(
    top = 0,
    navigators = "RCSCountryLeaf(buckets:20)"
)
response.data.raw["Navigators"]["RCSCountryLeaf"]["Buckets"]
# Out:
# [{'Label': 'United States', 'Count': 11826864},
#  {'Label': 'Eurobond Market', 'Count': 3617763},
#  {'Label': 'Colombia', 'Count': 1264380},
#  {'Label': 'China (Mainland)', 'Count': 1231247},
#  {'Label': 'South Korea', 'Count': 533448},
#  {'Label': 'Germany', 'Count': 469694},
#  {'Label': 'Canada', 'Count': 374139},
#  {'Label': 'France', 'Count': 221040},
#  {'Label': 'India', 'Count': 186007},
#  {'Label': 'Japan', 'Count': 157262},
#  {'Label': 'Chile', 'Count': 151908},
#  {'Label': 'Italy', 'Count': 135888},
#  {'Label': 'Australia', 'Count': 86496},
#  {'Label': 'Spain', 'Count': 58537},
#  {'Label': 'Switzerland', 'Count': 58249},
#  {'Label': 'Russia', 'Count': 56044},
#  {'Label': 'Austria', 'Count': 55356},
#  {'Label': 'Norway', 'Count': 52819},
#  {'Label': 'United Kingdom', 'Count': 50463},
#  {'Label': 'Malaysia', 'Count': 49591}]

# %%
# RCSCurrencyLeaf
# Specific to some assets, will allow you to narrow your search to focus on a specific currency.  Just pull out the top 20.
response = rdp.Search.search(
    top = 0,
    navigators = "RCSCurrencyLeaf(buckets:20)"
)
response.data.raw["Navigators"]["RCSCurrencyLeaf"]["Buckets"]
# Out:
# [{'Label': 'US Dollar', 'Count': 31827824},
#  {'Label': 'Euro', 'Count': 29873627},
#  {'Label': 'Chinese Yuan', 'Count': 2057987},
#  {'Label': 'US Cent', 'Count': 1645277},
#  {'Label': 'Colombian Peso', 'Count': 1437443},
#  {'Label': 'Japanese Yen', 'Count': 1003376},
#  {'Label': 'Hong Kong Dollar', 'Count': 855055},
#  {'Label': 'Canadian Dollar', 'Count': 852598},
#  {'Label': 'Swiss Franc', 'Count': 783202},
#  {'Label': 'Swedish Krona', 'Count': 736357},
#  {'Label': 'British Pound', 'Count': 723766},
#  {'Label': 'Korean (South) Won', 'Count': 706236},
#  {'Label': 'Indian Rupee', 'Count': 698534},
#  {'Label': 'Australian Dollar', 'Count': 443559},
#  {'Label': 'British Penny', 'Count': 439565},
#  {'Label': 'Hungarian Forint', 'Count': 347733},
#  {'Label': 'Norwegian Krone', 'Count': 321881},
#  {'Label': 'South African Rand', 'Count': 274034},
#  {'Label': 'Turkish Lira', 'Count': 237655},
#  {'Label': 'Taiwanese Dollar', 'Count': 233689}]

# %%
# RCSTRBC2012Leaf
# Represents the industry sector.  For example, if I query for Apple Computers, I will get many different industry sectors such as: 
# 'Computer Hardware (NEC)', 'Laptop & Desktop Computers', 'Phones & Smart Phones', etc.
response = rdp.Search.search(
    top = 0,
    navigators = "RCSTRBC2012Leaf(buckets:20)"
)
response.data.raw["Navigators"]["RCSTRBC2012Leaf"]["Buckets"]
# Out:
# [{'Label': 'Banks (NEC)', 'Count': 3694760},
#  {'Label': 'Corporate Financial Services (NEC)', 'Count': 2835010},
#  {'Label': 'Corporate Banks', 'Count': 1642560},
#  {'Label': 'Retail & Mortgage Banks', 'Count': 1270319},
#  {'Label': 'Public Finance Activities', 'Count': 883569},
#  {'Label': 'Investment Banking & Brokerage Services (NEC)', 'Count': 593184},
#  {'Label': 'Consumer Lending (NEC)', 'Count': 377980},
#  {'Label': 'Investment Management & Fund Operators (NEC)', 'Count': 363388},
#  {'Label': 'Electric Utilities (NEC)', 'Count': 283037},
#  {'Label': 'Investment Holding Companies (NEC)', 'Count': 276300},
#  {'Label': 'Diversified Investment Services', 'Count': 262055},
#  {'Label': 'Wealth Management', 'Count': 247821},
#  {'Label': 'Construction & Engineering (NEC)', 'Count': 240162},
#  {'Label': 'Real Estate Rental, Development & Operations (NEC)',
#   'Count': 237371},
#  {'Label': 'Compliance & Investor Communication', 'Count': 226729},
#  {'Label': 'Business Support Services (NEC)', 'Count': 201627},
#  {'Label': 'Building Contractors', 'Count': 197225},
#  {'Label': 'Financial & Commodity Market Operators & Service Providers (NEC)',
#   'Count': 179814},
#  {'Label': 'UK Investment Trusts', 'Count': 160977},
#  {'Label': 'Management Consulting Services', 'Count': 153825}]

# %%
# RCSTRBC2012Leaf
# RCSTRBC2012Genealogy
# RCSTRBC2012Name
# Provide a breakdown of the hierarchy defined for many of these RCS attributes.  You can see the mapping between the 
# hierarchy defined with the Genealogy property and Name property.  
# For example, the code 'B:262' maps to the name 'Banking & Investment Services'.
response = rdp.Search.search(
    filter = "RCSTRBC2012Leaf eq 'Banks'",    # Limit the sector to banks so we can easily observe the output below
    top = 0,
    navigators = "RCSTRBC2012Leaf, RCSTRBC2012Genealogy, RCSTRBC2012Name"
)
response.data.raw
# Out:
# {'Warnings': ["'RCSTRBC2012' is not navigable"],
#  'Total': 6669150,
#  'Hits': [],
#  'Navigators': {'RCSTRBC2012Genealogy': {'Buckets': [{'Label': 'B:261\\B:262\\B:127\\B:128\\B:1615',
#      'Count': 3666976},
#     {'Label': 'B:261\\B:262\\B:127\\B:128\\B:1616', 'Count': 1626315},
#     {'Label': 'B:261\\B:262\\B:127\\B:128\\B:1617', 'Count': 1261544},
#     {'Label': 'B:261\\B:262\\B:127\\B:128\\B:1619', 'Count': 35409},
#     {'Label': 'B:261\\B:262\\B:127\\B:131\\B:1629', 'Count': 20055},
#     {'Label': 'B:261\\B:262\\B:263\\B:207\\B:1638', 'Count': 3857},
#     {'Label': 'B:261\\B:262\\B:127\\B:128\\B:1618', 'Count': 494},
#     {'Label': 'B:261\\B:262\\B:127\\B:128\\B:1620', 'Count': 365}]},
#   'RCSTRBC2012Leaf': {'Buckets': [{'Label': 'Banks (NEC)', 'Count': 3694791},
#     {'Label': 'Corporate Banks', 'Count': 1642562},
#     {'Label': 'Retail & Mortgage Banks', 'Count': 1270384},
#     {'Label': 'Private Banks', 'Count': 36229},
#     {'Label': 'Import-Export Banks', 'Count': 20351},
#     {'Label': 'Merchant Banks', 'Count': 3883},
#     {'Label': 'Money Center Banks', 'Count': 541},
#     {'Label': 'Islamic Banks', 'Count': 409}]},
#   'RCSTRBC2012Name': {'Buckets': [{'Label': 'Financials\\Banking & Investment Services\\Banking Services\\Banks\\Banks (NEC)',
#      'Count': 3666976},
#     {'Label': 'Financials\\Banking & Investment Services\\Banking Services\\Banks\\Corporate Banks',
#      'Count': 1626315},
#     {'Label': 'Financials\\Banking & Investment Services\\Banking Services\\Banks\\Retail & Mortgage Banks',
#      'Count': 1261544},
#     {'Label': 'Financials\\Banking & Investment Services\\Banking Services\\Banks\\Private Banks',
#      'Count': 35409},
#     {'Label': 'Financials\\Banking & Investment Services\\Banking Services\\Corporate Financial Services\\Import-Export Banks',
#      'Count': 20055},
#     {'Label': 'Financials\\Banking & Investment Services\\Investment Banking & Investment Services\\Investment Banking & Brokerage Services\\Merchant Banks',
#      'Count': 3857},
#     {'Label': 'Financials\\Banking & Investment Services\\Banking Services\\Banks\\Money Center Banks',
#      'Count': 494},
#     {'Label': 'Financials\\Banking & Investment Services\\Banking Services\\Banks\\Islamic Banks',
#      'Count': 365}]}}}

# %% [markdown]
# The above output includes 3 separate sections: RCSTRBC2012Genealogy, RCSTRBC2012Leaf and RCSTRBC2012Name.  For each you can see a breakdown ot the buckets.
