# %% [markdown]
# ## Sorting and Grouping
# The Search service offers the ability to organize your result set in different ways.  Whether you choose to sort based on a specific property, group properties or boost the result set, you have the option to override the default ordering returned. In addition, you can also use navigation to organize your buckets of data returned.
#
# By default, the result set will provide some basic ranking, depending on the type of query or filter performed.

# %%
import refinitiv.dataplatform as rdp
import pandas as pd

rdp.open_desktop_session('Your API Key here')

# %%
pd.set_option('display.max_colwidth', 140)
rdp.__version__
# Out:
# '1.0.0a7.post1'

# %% [markdown]
# #### Example - Default ranking and how to boost results
# To demonstrate default sorting, I'm going to search for documents that match a specific ticker. This will result in the documents ranked based on the relevancy and scores assigned to each document.
#
# Search for Vodafone (VOD) against the ticker:

# %%
rdp.search(
    filter = "TickerSymbol eq 'VOD'",
    select = "_, RCSExchangeCountryLeaf"
)
# Out:
#                                                                                                                                  DocumentTitle  \
# 0                                                                                    Vodafone Group PLC, Ordinary Share, London Stock Exchange
# 1                                                                               Vodacom Group Ltd, Ordinary Share, Johannesburg Stock Exchange
# 2  Johannesburg Stock Exchange Vodacom Group Limited Cash Settled SSF Equity Future Continuation 1, Equity Future, ZAR, Johannesburg Stock ...
# 3                Johannesburg Stock Exchange Can Do VODX Vodacom Equity Future Continuation 1, Equity Future, ZAR, Johannesburg Stock Exchange
# 4                  Johannesburg Stock Exchange Vodacom Group CFD Equity Future Continuation 1, Equity Future, ZAR, Johannesburg Stock Exchange
# 5  Johannesburg Stock Exchange Vodacom Group Limited Cash Settled CFD Sabor Equity Future Continuation 1, Equity Future, ZAR, Johannesburg ...
# 6  Johannesburg Stock Exchange Vodacom Group Ltd SSF Cash Settled Dividend Neutral Equity Future Continuation 1, Equity Future, ZAR, Johann...
# 7  Johannesburg Stock Exchange Vodafone Group PLC Dividend Neutral Equity Future Continuation 1, Equity Future, ZAR, Johannesburg Stock Exc...
# 8             Johannesburg Stock Exchange Vodafone Group PLC IDX Equity Future Continuation 1, Equity Future, ZAR, Johannesburg Stock Exchange
# 9                  Johannesburg Stock Exchange Vodacom Group SSF Equity Future Continuation 1, Equity Future, ZAR, Johannesburg Stock Exchange
#
#           PI BusinessEntity RCSExchangeCountryLeaf       PermID        RIC
# 0    1049261   QUOTExEQUITY         United Kingdom  55836053361      VOD.L
# 1   59938825   QUOTExEQUITY           South Africa  55849756323     VODJ.J
# 2  113268320   QUOTExEQUITY           South Africa  21508525903     VODSc1
# 3  148452798   QUOTExEQUITY           South Africa  21534036541   VODXFLc1
# 4  244233208   QUOTExEQUITY           South Africa  21600821292   VODCFDc1
# 5  363600087   QUOTExEQUITY           South Africa  21693141305  VODSCFDc1
# 6  381845837   QUOTExEQUITY           South Africa  21707726176     VODTc1
# 7   53826719   QUOTExEQUITY           South Africa  21481060885     VODDc1
# 8   53826752   QUOTExEQUITY           South Africa  21481060918     VODGc1
# 9   60188651   QUOTExEQUITY           South Africa  21481084690     VODQc1

# %% [markdown]
# The above output ranked the common share 'VOD.L', listed within the UK, at the top.  This is largely due to the fact that 'VOD.L' is the most significant or liquid asset in the list. However, if I decide to override this default ranking by specifying that I want to show the listed documents within the Unitied States at the top, I can do this
# by applying a *Boost* parameter.

# %%
rdp.search(
    filter = "TickerSymbol eq 'VOD'",
    boost = "RCSExchangeCountryLeaf eq 'United States'",
    select = "_, RCSExchangeCountryLeaf"
)
# Out:
#                                                                                              DocumentTitle  \
# 0                                Vodafone Group PLC, Depository Receipt, NASDAQ Global Select Consolidated
# 1                       Vodafone Group PLC, Depository Receipt, NASDAQ Stock Exchange Global Select Market
# 2                  Vodafone Group PLC, Depository Receipt, Cboe BZX Exchange - Nasdaq Global Select Market
# 3                 Vodafone Group PLC, Depository Receipt, Cboe EDGX Exchange - Nasdaq Global Select Market
# 4               Vodafone Group PLC, Depository Receipt, Boston SE when trading NASDAQ Global Select Market
# 5               Vodafone Group PLC, Depository Receipt, NYSE Arca when trading NASDAQ Global Select Market
# 6                  Vodafone Group PLC, Depository Receipt, Cboe BYX Exchange - Nasdaq Global Select Market
# 7                 Vodafone Group PLC, Depository Receipt, Cboe EDGA Exchange - Nasdaq Global Select Market
# 8                             Vodafone Group PLC, Depository Receipt, NASDAQ OMX PHLX Global Select Market
# 9  Vodafone Group PLC, Depository Receipt, NYSE National Exchange when trading Nasdaq Global Select Market
#
#          PI BusinessEntity RCSExchangeCountryLeaf       PermID     RIC
# 0    726233   QUOTExEQUITY          United States  55839401038   VOD.O
# 1   1092283   QUOTExEQUITY          United States  55835364259  VOD.OQ
# 2  53705532   QUOTExEQUITY          United States  55845638958   VOD.Z
# 3  73238578   QUOTExEQUITY          United States  21475045362  VOD.DG
# 4  55957391   QUOTExEQUITY          United States  55846134804   VOD.B
# 5    754172   QUOTExEQUITY          United States  55837254988   VOD.P
# 6  76383634   QUOTExEQUITY          United States  21475122433  VOD.ZY
# 7  73240457   QUOTExEQUITY          United States  21475045135  VOD.DY
# 8  76271998   QUOTExEQUITY          United States  21475115114  VOD.PH
# 9    735992   QUOTExEQUITY          United States  55838271132   VOD.C

# %% [markdown]
# #### Example - List the youngest CEO's.
# The order_by parameters will sort, ascending (default) or descending, based on the birth year property.
#
# Note: In the following example, not every document that identifies a CEO will have a reported birth year. Because we are sorting based on the year they were born,
# all CEO's where the year of birth is not recorded will be bumped to the bottom of the list.

# %%
rdp.search(
    view = rdp.SearchViews.People,
    filter = "OfficerDirector(RoleTitleCode eq 'CEO' and RoleStatus eq 'Active')",
    order_by = "YearOfBirth desc, LastName, FirstName",
    select = "FullName, YearOfBirth, DTCharacteristics, PrimaryOfficerDirectorRIC, PrimaryOfficerDirector"
)
# Out:
#   PrimaryOfficerDirectorRIC      PrimaryOfficerDirector  YearOfBirth  \
# 0                 OMRPI.RTS      Omskiy Rechnoy Port AO         1991
# 1                    CHR.TA       Chiron Refineries Ltd         1991
# 2                 058220.KQ        Arion Technology Inc         1990
# 3                  DASA3.SA  Diagnosticos da America SA         1990
# 4                    4493.T    Cyber Security Cloud Inc         1990
# 5                   LIBD.BO       Libord Securities Ltd         1989
# 6                  CLNKb.ST                  Cellink AB         1989
# 7                    7352.T    Branding Engineer Co Ltd         1989
# 8                     BSR.V     Bluestone Resources Inc         1989
# 9                    3989.T       Sharingtechnology Inc         1989
#
#                                              DTCharacteristics  \
# 0                             General Director (CEO), Director
# 1                                      Chief Executive Officer
# 2                            Chief Executive Officer, Director
# 3                            Chief Executive Officer, Director
# 4  President, Chief Executive Officer, Representative Director
# 5                                      Chief Executive Officer
# 6                            Chief Executive Officer, Director
# 7             Chief Executive Officer, Representative Director
# 8                            Chief Executive Officer, Director
# 9             Chief Executive Officer, Representative Director
#
#                       FullName
# 0  Grigory Sergeevich Sandulov
# 1            Yehonatan Shachar
# 2              Myeong Jin Chae
# 3         Pedro de Godoy Bueno
# 4                  Hikaru Ohno
# 5                Vinit Agrawal
# 6               Erik Gatenholm
# 7            Yasuyuki Kawabata
# 8             Jack O.A. Lundin
# 9           Nobuhiro Moriyoshi

# %% [markdown]
# Instead of sorting by the year of birth, let's organize the output so the company is grouped.
#
# **Note**: While we can see the company's grouped, we can also observe the many of the entries do not have a year of birth recorded.

# %%
rdp.search(
    view = rdp.SearchViews.People,
    filter = "OfficerDirector(RoleTitleCode eq 'CEO' and RoleStatus eq 'Active')",
    group_by = "PrimaryOfficerDirector",
    top = 20,
    select = "FullName, YearOfBirth, DTCharacteristics, PrimaryOfficerDirectorRIC, PrimaryOfficerDirector"
)
# Out:
#    PrimaryOfficerDirectorRIC     PrimaryOfficerDirector  YearOfBirth  \
# 0                     MSFT.O             Microsoft Corp         <NA>
# 1                     MSFT.O             Microsoft Corp         <NA>
# 2                     AAPL.O                  Apple Inc         1950
# 3                     AAPL.O                  Apple Inc         <NA>
# 4                     AMZN.O             Amazon.com Inc         <NA>
# 5                     AMZN.O             Amazon.com Inc         <NA>
# 6                     AMZN.O             Amazon.com Inc         1957
# 7                    GOOGL.O               Alphabet Inc         1972
# 8                    GOOGL.O               Alphabet Inc         <NA>
# 9                       FB.O               Facebook Inc         <NA>
# 10                      FB.O               Facebook Inc         <NA>
# 11                      FB.O               Facebook Inc         <NA>
# 12                      BRKa     Berkshire Hathaway Inc         1930
# 13                      BRKa     Berkshire Hathaway Inc         <NA>
# 14                      BRKa     Berkshire Hathaway Inc         1959
# 15                    BABA.K  Alibaba Group Holding Ltd         1972
# 16                    BABA.K  Alibaba Group Holding Ltd         <NA>
# 17                   0700.HK       Tencent Holdings Ltd         <NA>
# 18                         V                   Visa Inc         <NA>
# 19                       JNJ          Johnson & Johnson         <NA>
#
#                                             DTCharacteristics  \
# 0             Independent Non-Executive Chairman of the Board
# 1                           Chief Executive Officer, Director
# 2                           Independent Chairman of the Board
# 3                           Chief Executive Officer, Director
# 4   Chairman of the Board, President, Chief Executive Officer
# 5                                                    Director
# 6                                        Independent Director
# 7                           Chief Executive Officer, Director
# 8                                        Independent Director
# 9     Chairman of the Board, Chief Executive Officer, Founder
# 10                                Venture Economics Executive
# 11                                Venture Economics Executive
# 12             Chairman of the Board, Chief Executive Officer
# 13         Vice Chairman � Non Insurance Operations, Director
# 14                                       Independent Director
# 15             Chairman of the Board, Chief Executive Officer
# 16                               President - Taobao and Tmall
# 17   Executive Chairman of the Board, Chief Executive Officer
# 18             Chairman of the Board, Chief Executive Officer
# 19             Chairman of the Board, Chief Executive Officer
#
#                  FullName
# 0   John Wendell Thompson
# 1           Satya Nadella
# 2         Art D. Levinson
# 3             Tim D. Cook
# 4           Jeff P. Bezos
# 5   Keith Brian Alexander
# 6       Jon J. Rubinstein
# 7           Sundar Pichai
# 8       Roger W. Ferguson
# 9         Mark Zuckerberg
# 10    Dustin A. Moskovitz
# 11          Adam D'Angelo
# 12  Warren Edward Buffett
# 13        Gregory E. Abel
# 14         Steve B. Burke
# 15           Daniel Zhang
# 16              Fan Jiang
# 17             Huateng Ma
# 18       Al Francis Kelly
# 19            Alex Gorsky

# %% [markdown]
# #### Example - Sorting using Navigators
# By default, when you use a navigator against a property, it will sort all results based on the number of matches for each value within a bucket.  For example, if I were to list the top 10 exchanges within Canada, we can see the count value ranked, indicating the number instruments matched on that exchange.

# %%
response = rdp.Search.search(
    view = rdp.SearchViews.EquityQuotes,
    filter = "RCSExchangeCountryLeaf eq 'Canada'",
    top = 0,
    navigators = "ExchangeName(buckets:10)"
)
response.data.raw["Navigators"]["ExchangeName"]["Buckets"]
# Out:
# [{'Label': 'Montreal Options Exchange', 'Count': 43939},
#  {'Label': 'Montreal Exchange', 'Count': 25214},
#  {'Label': 'The Toronto Stock Exchange', 'Count': 11452},
#  {'Label': 'Nasdaq CXC', 'Count': 9809},
#  {'Label': 'Canadian Securities Exchange/PURE - CSE Listed & Other Canadian Listed Securities',
#   'Count': 8094},
#  {'Label': 'Canadian Composite Quote/Trade', 'Count': 7795},
#  {'Label': 'TSX Venture Exchange (former Canadian Ventures Exchange)',
#   'Count': 7103},
#  {'Label': 'Alpha - Canadian ATS', 'Count': 7014},
#  {'Label': 'Omega - Candian ATS', 'Count': 7002},
#  {'Label': 'Nasdaq CX2', 'Count': 6528}]

# %% [markdown]
# Using the above example, I can instead choose to sort based on the average daily volume within the exchange.  The following search will result in the top 5 Canadian exchanges, ranked based on the 90 day average volume:

# %%
response = rdp.Search.search(
    view = rdp.SearchViews.EquityQuotes,
    filter = "RCSExchangeCountryLeaf eq 'Canada'",
    top = 0,
    navigators = "ExchangeName(buckets:5, desc:sum_AvgVol90D)"
)

# %%
# Pretty display of the listing
data = []
for exch in response.data.raw["Navigators"]["ExchangeName"]["Buckets"]:
    data.append([exch["Label"], f'{exch["sum_AvgVol90D"]:,}'])

pd.DataFrame(data, columns=["Exchange", "Average 90-day Volume"])
# Out:
#                                                                             Exchange  \
# 0                                                     Canadian Composite Quote/Trade
# 1                                                         The Toronto Stock Exchange
# 2                           TSX Venture Exchange (former Canadian Ventures Exchange)
# 3                                          Canadian Securities Exchange - CSE Listed
# 4  Canadian Securities Exchange/PURE - CSE Listed & Other Canadian Listed Securities
#
#   Average 90-day Volume
# 0       1,842,647,193.0
# 1       1,046,694,609.0
# 2         428,343,773.0
# 3         122,854,222.0
# 4          50,203,424.0
